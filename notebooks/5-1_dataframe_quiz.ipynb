# %% [markdown]
# # Answer Key to the Data Wrangling with DataFrames Coding Quiz
#
# Helpful resources:
# https://spark.apache.org/docs/2.4.0/api/python/pyspark.sql.html

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import isnan, count, when, col, desc, udf, col, sort_array, asc, avg
from pyspark.sql.functions import sum as Fsum
from pyspark.sql.window import Window
from pyspark.sql.types import IntegerType

# %%
# 1) import any other libraries you might need
# 2) instantiate a Spark session 
# 3) read in the data set located at the path "data/sparkify_log_small.json"
# 4) write code to answer the quiz questions 

spark = SparkSession \
    .builder \
    .appName("Data Frames practice") \
    .getOrCreate()

df = spark.read.json("data/music_log_small.json")
# Out:
# 26/05/11 17:52:18 WARN Utils: Your hostname, codespaces-4701ab resolves to a loopback address: 127.0.0.1; using 10.0.10.239 instead (on interface eth0)
# 26/05/11 17:52:18 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/11 17:52:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/05/11 17:52:20 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/05/11 17:52:20 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 26/05/11 17:52:20 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 26/05/11 17:52:20 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 26/05/11 17:52:20 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.

# %% [markdown]
# # Question 1
#
# Which page did user id "" (empty string) NOT visit?

# %%
df.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
# download from google storage
import requests

url = 'https://storage.googleapis.com/files-bb-bot/music_log.json'
r = requests.get(url)
with open('./data/music_log.json', 'wb') as f:
    f.write(r.content)

# %%
# reading the json file into a DataFrame
path = "data/music_log.json"
user_log = spark.read.json(path)

# %%
from pyspark.sql.functions import trim
user_log_valid = user_log_valid.filter(trim(user_log_valid["userId"]) = "")

# %% [markdown]
# # Question 2 - Reflect
#
# What type of user does the empty string user id most likely refer to?

# %% [markdown]
# # Question 3
#
# How many female users do we have in the data set?

# %% [markdown]
# # Question 4
#
# How many songs were played from the most played artist?

# %% [markdown]
# # Question 5 (challenge)
#
# How many songs do users listen to on average between visiting our home page? Please round your answer to the closest integer.
