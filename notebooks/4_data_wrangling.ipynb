# %% [markdown]
# # Data Wrangling with Spark
#
# These first three cells import libraries, instantiate a SparkSession, and then read in the data set

# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StringType
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import desc
from pyspark.sql.functions import asc
from pyspark.sql.functions import sum as Fsum

# %%
# maybe VS Code doesn't support this magic command, but in Jupyter notebooks it allows us to display plots inline, directly below the code that generates them. This is useful for data analysis and visualization, as it allows us to see the results of our code immediately without having to open a separate window for the plot.
# %matplotlib inline

# %%
#Creating a spark session
spark = SparkSession \
    .builder \
    .appName("Wrangling Data") \
    .getOrCreate()
# Out:
# 26/05/11 16:51:59 WARN Utils: Your hostname, codespaces-4701ab resolves to a loopback address: 127.0.0.1; using 10.0.10.239 instead (on interface eth0)
# 26/05/11 16:51:59 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/11 16:52:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/05/11 16:52:01 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/05/11 16:52:01 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %% [markdown]
# #### For this exercise we will download a much larger dataset that will be used in the following exercises

# %%
# download from google storage
import requests

url = 'https://storage.googleapis.com/files-bb-bot/music_log.json'
r = requests.get(url)
with open('./data/music_log.json', 'wb') as f:
    f.write(r.content)

# %%
# reading the json file into a DataFrame
path = "data/music_log.json"
user_log = spark.read.json(path)

# %%
## You'll see that this has much more entries
print(user_log.count())
# Out:
# [Stage 1:>                                                          (0 + 2) / 2]
# 286500

# %% [markdown]
# # Data Exploration
#
# The next cells explore the data set.

# %%
# First 5 entries
user_log.take(5)
# Out:
# [Row(artist='Martha Tilston', auth='Logged In', firstName='Colin', gender='M', itemInSession=50, lastName='Freeman', length=277.89016, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Rockpools', status=200, ts=1538352117000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='30'),
#  Row(artist='Five Iron Frenzy', auth='Logged In', firstName='Micah', gender='M', itemInSession=79, lastName='Long', length=236.09424, level='free', location='Boston-Cambridge-Newton, MA-NH', method='PUT', page='NextSong', registration=1538331630000, sessionId=8, song='Canada', status=200, ts=1538352180000, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"', userId='9'),
#  Row(artist='Adam Lambert', auth='Logged In', firstName='Colin', gender='M', itemInSession=51, lastName='Freeman', length=282.8273, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Time For Miracles', status=200, ts=1538352394000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='30'),
#  Row(artist='Enigma', auth='Logged In', firstName='Micah', gender='M', itemInSession=80, lastName='Long', length=262.71302, level='free', location='Boston-Cambridge-Newton, MA-NH', method='PUT', page='NextSong', registration=1538331630000, sessionId=8, song='Knocking On Forbidden Doors', status=200, ts=1538352416000, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"', userId='9'),
#  Row(artist='Daft Punk', auth='Logged In', firstName='Colin', gender='M', itemInSession=52, lastName='Freeman', length=223.60771, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Harder Better Faster Stronger', status=200, ts=1538352676000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='30')]

# %%
user_log.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
user_log.describe("sessionId").show()
# Out:
# [Stage 5:>                                                          (0 + 2) / 2]
# +-------+-----------------+
# |summary|        sessionId|
# +-------+-----------------+
# |  count|           286500|
# |   mean|1041.526554973822|
# | stddev|726.7762634630783|
# |    min|                1|
# |    max|             2474|
# +-------+-----------------+

# %%
user_log.count()
# Out:
# 286500

# %% [markdown]
# Now, in order to know the distinct pages in the dataset, we can use the following approach.
#
# By selecting the `page` column, removing duplicate entries with `dropDuplicates()`, and sorting the results alphabetically using `sort("page")`, we get a clean list of all unique page names. Finally, `show()` displays the output.
#
# If you're looking for alternatives, you could use:
# ```python
# user_log.select("page").distinct().orderBy("page").show()

# %%
# which pages exist in the dataset? (page is a column in the schema)
user_log.select("page").dropDuplicates().sort("page").show()
# Out:
# [Stage 14:>                                                         (0 + 2) / 2]
# +--------------------+
# |                page|
# +--------------------+
# |               About|
# |          Add Friend|
# |     Add to Playlist|
# |              Cancel|
# |Cancellation Conf...|
# |           Downgrade|
# |               Error|
# |                Help|
# |                Home|
# |               Login|
# |              Logout|
# |            NextSong|
# |            Register|
# |         Roll Advert|
# |       Save Settings|
# |            Settings|
# |    Submit Downgrade|
# | Submit Registration|
# |      Submit Upgrade|
# |         Thumbs Down|
# +--------------------+
# only showing top 20 rows

# %%
user_log.select("page").distinct().orderBy("page").show()
# Out:
# [Stage 17:>                                                         (0 + 2) / 2]
# +--------------------+
# |                page|
# +--------------------+
# |               About|
# |          Add Friend|
# |     Add to Playlist|
# |              Cancel|
# |Cancellation Conf...|
# |           Downgrade|
# |               Error|
# |                Help|
# |                Home|
# |               Login|
# |              Logout|
# |            NextSong|
# |            Register|
# |         Roll Advert|
# |       Save Settings|
# |            Settings|
# |    Submit Downgrade|
# | Submit Registration|
# |      Submit Upgrade|
# |         Thumbs Down|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Query Data

# %% [markdown]
# Now, if we want to filter the dataset to see all records where the `userId` is "100001", we can use this query. It selects the columns `userId`, `firstname`, `page`, and `song`, applies a filter with `.where()`, and retrieves the data using `.collect()`.
#
# This approach is useful when you want to:
# 1. Focus on specific columns of interest.
# 2. Examine all data associated with a particular `userId`.
# 3. Fetch the filtered rows as a list of Python objects (since `.collect()` pulls the data into memory).
#
# If you don't want to load all results into memory, you could use `.show()` instead of `.collect()` to preview the data directly in the console:
# ```python
# user_log.select(["userId", "firstname", "page", "song"]).where(user_log.userId == "100001").show()

# %%
user_log.select(["userId", "firstname", "page", "song"]).where(user_log.userId == "100001").collect()
# Out:
# [Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Just Dance'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Kids With Guns (Quiet Village Remix)'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="Do You Think I'm Spooky?"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="Can't Hardly Wait (Remastered Version)"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Propane Nightmares'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Falling'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Runaway'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='My Enemy'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Rise Above (Live) (Album Version)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='The Middle'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Break It Off'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Around The Way Girl'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='All I Ever Wanted'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Leavin'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='End Of The Line (Album Version)'),
#  Row(userId='100001', firstname='Delaney', page='Logout', song=None),
#  Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Undo'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Frankie Machine (Part Two)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="It's Getting Boring By The Sea"),
#  Row(userId='100001', firstname='Delaney', page='Thumbs Down', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Cavity Search (Paody of "Hold Me_ Thrill Me_ Kiss Me_ Kill Me" by U2)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Almaz'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="You're The One"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='All My Friends'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Too Young'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='It Takes Two'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Fly Like An Eagle'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Mushrooms'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='I Will Love You'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Take What You Take'),
#  Row(userId='100001', firstname='Delaney', page='Logout', song=None),
#  Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Rigs Of The Time'),
#  Row(userId='100001', firstname='Delaney', page='Add Friend', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Sehr kosmisch'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Curve of the Earth'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Just Lose It'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="It's Not Easy"),
#  Row(userId='100001', firstname='Delaney', page='Thumbs Up', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='The Day After Tomorrow'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='If I Could'),
#  Row(userId='100001', firstname='Delaney', page='Add to Playlist', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Blood To Bleed'),
#  Row(userId='100001', firstname='Delaney', page='Logout', song=None),
#  Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Resignation (Live) (Album Version)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Woman'),
#  Row(userId='100001', firstname='Delaney', page='Thumbs Up', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="Wong Chia Chi's Theme"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Hero'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="You're The One"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Bossa (Digitally Remastered)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Bury The Living'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Pursuit Of Happiness (nightmare)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Smile'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Coffee And TV'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Dog Days Are Over (Radio Edit)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='I Wanna Be Your Lover (LP Version)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='The Pulse'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Undo'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Tired Of Waiting For You'),
#  Row(userId='100001', firstname='Delaney', page='Settings', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='If Tomorrow Never Comes'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Almost Crimes'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='To Be A Lover'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Get Stupid Fresh Part 1 (2005 Digital Remaster)'),
#  Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Kiss With A Fist'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Shit On The Radio (Remember The Days)'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Who Will Save Your Soul'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Wish We Were Older'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Take It From Here'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="Don't You Think?"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Indian Summer'),
#  Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Man Research (Clapper)'),
#  Row(userId='100001', firstname='Delaney', page='Thumbs Down', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Intermission 1'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Who Died'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Blue Sky (Featuring Keith Urban)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="Come On_ Let's Go"),
#  Row(userId='100001', firstname='Delaney', page='Upgrade', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='ObservÃ\x83Â¡ndonos (SatÃ\x83Â©lites)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='CanÃ\x83Â§Ã\x83Â£o Para Um Grande Amor'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Dream On'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Travels With Myself - And Someone Else (Live)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Chopper'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Have You Ever Seen The Rain'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="Let's Get Loud"),
#  Row(userId='100001', firstname='Delaney', page='Thumbs Up', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Ã\x83Â\x9agyis tudom'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Where Did You Sleep Last Night'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Money (Album Version)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='West One (Shine On Me)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Karma Police'),
#  Row(userId='100001', firstname='Delaney', page='Thumbs Up', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Linus & Lucy'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Starz In Their Eyes'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='The Whale Song'),
#  Row(userId='100001', firstname='Delaney', page='Upgrade', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Love And Hate'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Electric Feel'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Jumping Jack Flash'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Vegas Collie (feat. A sample from Natvralism\x19s Nanoloop)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Rock A My Soul'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Le Courage Des Oiseaux'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='The Joke'),
#  Row(userId='100001', firstname='Delaney', page='Add to Playlist', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Raising Hell'),
#  Row(userId='100001', firstname='Delaney', page='Logout', song=None),
#  Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Wonderful Merciful Savior'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Lady Marmalade'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Fire Fire featuring Mr. Vegas'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Bring The Rain'),
#  Row(userId='100001', firstname='Delaney', page='Logout', song=None),
#  Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Texto Dictador'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Ali In The Jungle'),
#  Row(userId='100001', firstname='Delaney', page='Thumbs Up', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Me And Bobby McGee (Live)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="Can't Fight This Feeling"),
#  Row(userId='100001', firstname='Delaney', page='Add Friend', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Mr Vain'),
#  Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Werewolves Of London (LP Version)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='If It Means A Lot To You'),
#  Row(userId='100001', firstname='Delaney', page='Thumbs Up', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Sing'),
#  Row(userId='100001', firstname='Delaney', page='Thumbs Up', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Your Ex-Lover Is Dead (Album Version)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Where Did He Go'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="Love Comin' Down"),
#  Row(userId='100001', firstname='Delaney', page='Add to Playlist', song=None),
#  Row(userId='100001', firstname='Delaney', page='Thumbs Up', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Major Tom (Coming Home)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Forgot About Dre'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='D.A.N.C.E [MSTRKRFT Remix]'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="It Won't Be Long"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="Dil Se Re (from the film 'Dil Se')"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Only The Good Die Young (1998 Digital Remaster)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='I Got Rhythm'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Corn Bread'),
#  Row(userId='100001', firstname='Delaney', page='Error', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Hitsville U.K.'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Never Content'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Tie Me Down [feat. Ray J] (Amended Album Version)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='The Planets Bend Between Us'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Mild Child (Album)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="You're The One"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Canada'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Rescuing Penny'),
#  Row(userId='100001', firstname='Delaney', page='Logout', song=None),
#  Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='KC (LP Version)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Most Of All (Live)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="Tides (C's Movement #1)"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song="La Mort d'Arthur"),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Amapola'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='I Shall Believe'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Paris 2004'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Jamaica Roots II(Agora E Sempre)'),
#  Row(userId='100001', firstname='Delaney', page='Help', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Samba Da Bencao'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Quando_ Quando_ Quando (Album Version)'),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Alejandro'),
#  Row(userId='100001', firstname='Delaney', page='Logout', song=None),
#  Row(userId='100001', firstname='Delaney', page='Home', song=None),
#  Row(userId='100001', firstname='Delaney', page='NextSong', song='Sehr kosmisch'),
#  Row(userId='100001', firstname='Delaney', page='Roll Advert', song=None),
#  Row(userId='100001', firstname='Delaney', page='Cancel', song=None),
#  Row(userId='100001', firstname='Delaney', page='Cancellation Confirmation', song=None)]

# %% [markdown]
# # Calculating Statistics by Hour

# %% [markdown]
# Here, we define a user-defined function (UDF) named `get_hour`. This UDF takes a timestamp in milliseconds as input and converts it into an hour value.
# The conversion is achieved by dividing the timestamp by 1000 to convert it into seconds, and then using the `datetime` module to extract the hour from the resulting timestamp.
#
# UDFs like this are commonly used in Spark when you need to apply custom transformations that are not natively supported.
#
# In this case, the goal is likely to extract the hour component from a timestamp column in the dataset to perform time-based analysis or aggregations.

# %%
from pyspark.sql.functions import udf
get_hour = udf(lambda x: datetime.datetime.fromtimestamp(x / 1000.0).hour)

# %% [markdown]
# Here, we are creating a new column named `hour` in the `user_log` DataFrame. This column is derived by applying the previously defined `get_hour` UDF to the `ts` column (which likely contains timestamps in milliseconds). The result is the hour value extracted from the timestamp.
#
# This step is useful for adding a time-based feature to the DataFrame, enabling analysis or grouping by hour to uncover patterns or trends based on the time of day.

# %%
user_log = user_log.withColumn("hour", get_hour(user_log.ts))

# %%
user_log.show(n=1)
# Out:
# [Stage 21:>                                                         (0 + 1) / 1]
# +--------------+---------+---------+------+-------------+--------+---------+-----+---------------+------+--------+-------------+---------+---------+------+-------------+--------------------+------+----+
# |        artist|     auth|firstName|gender|itemInSession|lastName|   length|level|       location|method|    page| registration|sessionId|     song|status|           ts|           userAgent|userId|hour|
# +--------------+---------+---------+------+-------------+--------+---------+-----+---------------+------+--------+-------------+---------+---------+------+-------------+--------------------+------+----+
# |Martha Tilston|Logged In|    Colin|     M|           50| Freeman|277.89016| paid|Bakersfield, CA|   PUT|NextSong|1538173362000|       29|Rockpools|   200|1538352117000|Mozilla/5.0 (Wind...|    30|   0|
# +--------------+---------+---------+------+-------------+--------+---------+-----+---------------+------+--------+-------------+---------+---------+------+-------------+--------------------+------+----+
# only showing top 1 row

# %% [markdown]
# In this example, we add a new column named `logs_hour` to the `user_log` DataFrame.
# Instead of using a UDF, we leverage Spark's built-in functions:
#
# - `from_unixtime`: Converts the timestamp (in milliseconds) into a human-readable format by dividing it by 1000 to change it to seconds.
# - `hour`: Extracts the hour component from the resulting timestamp.
# - `col("ts")`: Refers to the `ts` column in the DataFrame.

# %%
from pyspark.sql.functions import hour, from_unixtime, col
logs_hours = user_log.withColumn("logs_hour", hour(from_unixtime(col("ts") / 1000)))
logs_hours.show(n=1)
# Out:
# +--------------+---------+---------+------+-------------+--------+---------+-----+---------------+------+--------+-------------+---------+---------+------+-------------+--------------------+------+----+---------+
# |        artist|     auth|firstName|gender|itemInSession|lastName|   length|level|       location|method|    page| registration|sessionId|     song|status|           ts|           userAgent|userId|hour|logs_hour|
# +--------------+---------+---------+------+-------------+--------+---------+-----+---------------+------+--------+-------------+---------+---------+------+-------------+--------------------+------+----+---------+
# |Martha Tilston|Logged In|    Colin|     M|           50| Freeman|277.89016| paid|Bakersfield, CA|   PUT|NextSong|1538173362000|       29|Rockpools|   200|1538352117000|Mozilla/5.0 (Wind...|    30|   0|        0|
# +--------------+---------+---------+------+-------------+--------+---------+-----+---------------+------+--------+-------------+---------+---------+------+-------------+--------------------+------+----+---------+
# only showing top 1 row

# %% [markdown]
# Now ife we want to calculate the number of songs played during each hour.
#
# This is achieved by filtering the `user_log` DataFrame to include only rows where the `page` column has the value `"NextSong"`, which likely represents a song play event.
#
# The steps are as follows:
#
# 1. **Filter**: Retain only rows where `page == "NextSong"`.
# 2. **GroupBy**: Group the filtered DataFrame by the `hour` column.
# 3. **Count**: Count the number of rows (songs played) in each hour group.
# 4. **OrderBy**: Sort the resulting groups by the `hour` column, cast as a float for proper numerical ordering.
#
# This operation results in a DataFrame showing how many songs were played in each hour of the day, sorted by the hour in ascending order.

# %%
songs_in_hour = (user_log
                 .filter(user_log.page == "NextSong")
                 .groupby(user_log.hour)
                 .count()
                 .orderBy(user_log.hour.cast("float")))

# %%
songs_in_hour.show()
# Out:
# [Stage 23:=============================>                            (1 + 1) / 2]
# +----+-----+
# |hour|count|
# +----+-----+
# |   0| 9062|
# |   1| 8388|
# |   2| 8336|
# |   3| 8355|
# |   4| 8147|
# |   5| 8178|
# |   6| 8054|
# |   7| 8091|
# |   8| 8253|
# |   9| 8498|
# |  10| 8882|
# |  11| 8830|
# |  12| 9326|
# |  13| 9644|
# |  14|10494|
# |  15|11354|
# |  16|11636|
# |  17|11460|
# |  18|11124|
# |  19|10930|
# +----+-----+
# only showing top 20 rows

# %% [markdown]
# Convert the `songs_in_hour` Spark DataFrame into a Pandas DataFrame using the `toPandas()` method, which allows us to work with the data locally in Pandas.
#
# After converting, we explicitly cast the `hour` column in the Pandas DataFrame to a numeric type using `pd.to_numeric`. This ensures that the `hour` values are treated as numbers, which is useful if they were initially strings or objects in the Pandas DataFrame.
#
# This is typically done to enable numerical operations, such as plotting or further processing, on the `hour` column.

# %%
songs_in_hour_pd = songs_in_hour.toPandas()
songs_in_hour_pd.hour = pd.to_numeric(songs_in_hour_pd.hour)

# %%
songs_in_hour_pd[songs_in_hour_pd['hour'] == 2]
# Out:
#    hour  count
# 2     2   8336

# %% [markdown]
# ### Plotting the data

# %% [markdown]
# Create a scatter plot visualizing the number of songs played during each hour of the day.

# %%
plt.scatter(songs_in_hour_pd["hour"], songs_in_hour_pd["count"])
plt.xlim(-1, 24);
plt.ylim(0, 1.2 * max(songs_in_hour_pd["count"]))
plt.xlabel("Hour")
plt.ylabel("Songs played");

# %% [markdown]
# # Drop Rows with Missing Values
#
# As you'll see, it turns out there are no missing values in the userID or session columns. But there are userID values that are empty strings.

# %%
## order by sessionId ascending
user_log.select("userId").dropDuplicates().sort("userId").show(5)
# Out:
# [Stage 34:>                                                         (0 + 2) / 2]
# +------+
# |userId|
# +------+
# |      |
# |    10|
# |   100|
# |100001|
# |100002|
# +------+
# only showing top 5 rows

# %% [markdown]
# ### Drop the empty ones

# %% [markdown]
# We create a new DataFrame `user_log_valid` by removing rows with missing values in the `user_log` DataFrame.
#
# The `dropna()` method is used to handle missing (null) values.
#
# 1. **`how="any"`**:
#    - This means that if **any** of the specified columns (`"userId"` or `"sessionId"`) contain a null value, the row will be dropped.
#    - Other possible options for `how`:
#      - `"all"`: Drops rows only if **all** specified columns are null.
#
# 2. **`subset=["userId", "sessionId"]`**:
#    - Specifies the columns to check for null values. Only rows with nulls in these columns are considered for removal.

# %%
user_log_valid = user_log.dropna(how = "any", subset = ["userId", "sessionId"])

# %% [markdown]
# Ensure that all rows with an empty or whitespace-only `userId` are removed from the `user_log_valid` DataFrame.

# %%
from pyspark.sql.functions import trim
user_log_valid = user_log_valid.filter(trim(user_log_valid["userId"]) != "")

# %%
user_log_valid.count()
# Out:
# 278154

# %%
user_log.count()
# Out:
# 286500

# %%
user_log_valid.select("userId").dropDuplicates().sort("userId").show(5)
# Out:
# [Stage 43:>                                                         (0 + 2) / 2]
# +------+
# |userId|
# +------+
# |    10|
# |   100|
# |100001|
# |100002|
# |100003|
# +------+
# only showing top 5 rows

# %% [markdown]
# # Tracking User Account Downgrades and Behavior Across Lifetime”

# %% [markdown]
# Now, if we look at our dataset, we know that at any given timestamp, a user is either a paid or free user based on the `level` column. However, this information alone doesn't tell us whether the user has previously upgraded or downgraded their account. Without this context, we cannot track the transitions users make between account levels, such as identifying when a user actively downgraded their account from paid to free.
#
# To track these transitions, we can flag specific log entries, such as those where a user submits a downgrade request (`page = "Submit Downgrade"`). By using a window function and a cumulative sum, we can identify and segment a user's activity into distinct phases:
# - **Pre-downgrade phase**: All activity before the first downgrade event.
# - **Post-downgrade phase(s)**: Activity after one or more downgrade events.
#
# This segmentation allows us to analyze user behavior before and after downgrading, providing insights into patterns that might predict downgrades or indicate how user engagement changes after transitioning to a free account.

# %% [markdown]
# Find when users downgrade their accounts and then flag those log entries.
#
# Then use a window function and cumulative sum to distinguish each user's data as either pre or post downgrade events.

# %%
user_log_valid.filter("page = 'Submit Downgrade'").show()
# Out:
# +------+---------+---------+------+-------------+---------+------+-----+--------------------+------+----------------+-------------+---------+----+------+-------------+--------------------+------+----+
# |artist|     auth|firstName|gender|itemInSession| lastName|length|level|            location|method|            page| registration|sessionId|song|status|           ts|           userAgent|userId|hour|
# +------+---------+---------+------+-------------+---------+------+-----+--------------------+------+----------------+-------------+---------+----+------+-------------+--------------------+------+----+
# |  NULL|Logged In|     Kael|     M|           47|    Baker|  NULL| paid|Kingsport-Bristol...|   PUT|Submit Downgrade|1533102330000|      249|NULL|   307|1538393619000|"Mozilla/5.0 (Mac...|   131|  11|
# |  NULL|Logged In|   Calvin|     M|           17| Marshall|  NULL| paid|      Pittsburgh, PA|   PUT|Submit Downgrade|1537120757000|      313|NULL|   307|1538516445000|"Mozilla/5.0 (Mac...|    38|  21|
# |  NULL|Logged In|  Kaylenn|     F|          354|  Jenkins|  NULL| paid|           Price, UT|   PUT|Submit Downgrade|1535903878000|      479|NULL|   307|1538835479000|"Mozilla/5.0 (Mac...|   141|  14|
# |  NULL|Logged In|    Colin|     M|          214|  Freeman|  NULL| paid|     Bakersfield, CA|   PUT|Submit Downgrade|1538173362000|      532|NULL|   307|1538995454000|Mozilla/5.0 (Wind...|    30|  10|
# |  NULL|Logged In|  Destiny|     F|            2|  Herring|  NULL| paid|Miami-Fort Lauder...|   PUT|Submit Downgrade|1536844410000|      378|NULL|   307|1538997356000|"Mozilla/5.0 (Win...|    20|  11|
# |  NULL|Logged In|   Sophia|     F|           42|    Perry|  NULL| paid|Los Angeles-Long ...|   PUT|Submit Downgrade|1533885783000|      632|NULL|   307|1539144047000|Mozilla/5.0 (Wind...|    12|   4|
# |  NULL|Logged In|      Zoe|     F|           23|    Patel|  NULL| paid|Providence-Warwic...|   PUT|Submit Downgrade|1532554781000|      487|NULL|   307|1539239742000|Mozilla/5.0 (Wind...|    11|   6|
# |  NULL|Logged In|   Parker|     M|          636| Williams|  NULL| paid|San Francisco-Oak...|   PUT|Submit Downgrade|1537188538000|      529|NULL|   307|1539244188000|"Mozilla/5.0 (iPh...|    61|   7|
# |  NULL|Logged In|   Oliver|     M|           89|  Gilbert|  NULL| paid|Philadelphia-Camd...|   PUT|Submit Downgrade|1535093367000|      725|NULL|   307|1539264337000|"Mozilla/5.0 (Mac...|    81|  13|
# |  NULL|Logged In|  Brayden|     M|          113|   Thomas|  NULL| paid|Los Angeles-Long ...|   PUT|Submit Downgrade|1534133898000|      734|NULL|   307|1539335599000|"Mozilla/5.0 (Mac...|    85|   9|
# |  NULL|Logged In|   Lucero|     F|           19|     Reed|  NULL| paid|Louisville/Jeffer...|   PUT|Submit Downgrade|1536642109000|      753|NULL|   307|1539337383000|"Mozilla/5.0 (Win...|   140|   9|
# |  NULL|Logged In|     Lily|     F|           69|  Barnett|  NULL| paid|Washington-Arling...|   PUT|Submit Downgrade|1537053412000|      812|NULL|   307|1539467798000|"Mozilla/5.0 (Mac...|    35|  21|
# |  NULL|Logged In|    Alexi|     F|           41|   Warren|  NULL| paid|Spokane-Spokane V...|   PUT|Submit Downgrade|1532482662000|      859|NULL|   307|1539608060000|Mozilla/5.0 (Wind...|    54|  12|
# |  NULL|Logged In|   Autumn|     F|           53|   Martin|  NULL| paid|     Gainesville, FL|   PUT|Submit Downgrade|1537749786000|      688|NULL|   307|1539608338000|"Mozilla/5.0 (Win...|    77|  12|
# |  NULL|Logged In|   Jaleel|     M|          180|Maldonado|  NULL| paid|         Boulder, CO|   PUT|Submit Downgrade|1537890437000|      510|NULL|   307|1539633167000|Mozilla/5.0 (Wind...|    59|  19|
# |  NULL|Logged In|    Piper|     F|          210|  Nielsen|  NULL| paid|New York-Newark-J...|   PUT|Submit Downgrade|1537699856000|      865|NULL|   307|1539647785000|"Mozilla/5.0 (Mac...|   103|  23|
# |  NULL|Logged In|    Faigy|     F|          101|     Howe|  NULL| paid|Phoenix-Mesa-Scot...|   PUT|Submit Downgrade|1538211832000|      826|NULL|   307|1539675894000|Mozilla/5.0 (Maci...|    95|   7|
# |  NULL|Logged In|  Ashlynn|     F|          303| Williams|  NULL| paid|     Tallahassee, FL|   PUT|Submit Downgrade|1537365219000|     1101|NULL|   307|1540235073000|"Mozilla/5.0 (Mac...|    74|  19|
# |  NULL|Logged In|  Brayden|     M|          105|   Thomas|  NULL| paid|Los Angeles-Long ...|   PUT|Submit Downgrade|1534133898000|     1183|NULL|   307|1540383285000|"Mozilla/5.0 (Mac...|    85|  12|
# |  NULL|Logged In|    Micah|     M|           11|     Long|  NULL| paid|Boston-Cambridge-...|   PUT|Submit Downgrade|1538331630000|     1276|NULL|   307|1540706007000|"Mozilla/5.0 (Win...|     9|   5|
# +------+---------+---------+------+-------------+---------+------+-----+--------------------+------+----------------+-------------+---------+----+------+-------------+--------------------+------+----+
# only showing top 20 rows

# %%
user_log.select(["userId", "firstname", "page", "level", "song"]).where(user_log.userId == "100025").collect()
# Out:
# [Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Marry Me'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Cannonball'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Voyage au Bout de l'Ennui (Journey to the End of the Night)"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The Privateers'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Dream On'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Make Love To Your Mind'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Like Glue (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Just A Song Before I Go'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Joy'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The Sun Also Sets'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Turn On The Sun Again'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sowing Season (Yeah)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Otra Sudestada'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Tempted To Touch'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="This Ain't A Scene_ It's An Arms Race"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='God Talk'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="I'll Go On Loving You"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Abracadabra'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The Summer'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Civil War'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sexual Sportswear'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='One Step Closer (Album Version)'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Suena tu guitarra'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='I Speak Because I Can'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Crimes Of The Heart'),
#  Row(userId='100025', firstname='London', page='Settings', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Settings', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Help', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='No Se Por Que Te Quiero (Con Antonio Banderas)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Rest'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Rags To Riches'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Immortal (Redux)'),
#  Row(userId='100025', firstname='London', page='Error', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Keep It Playa (Explicit) (Feat. Slim Thug)'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Tu Recuerdo'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Interlude'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Meteor'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Black Duck Blues'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='All My Only Dreams'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Born To Wander'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='How Am I Supposed To Live Without You'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Vanilla Radio'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Cruel To Be Kind'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Under Pressure'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Your Woman'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sancta Terra'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Moar Ghosts 'n' Stuff"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="I'm Housin'"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Mamma'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Infinity'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Lost In Stereo'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Hochmah (Interlude)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='deixe-se acreditar'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Stealing Happy Hours'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="What's On Your Mind"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Wild Hearted Son'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The Day We All Died'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sabbath Bloody Sabbath'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Little Annie's Christmas Wish"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Africa (Feat. Lisa Lore)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Submission'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Killing Me Softly With His Song'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Not This Time'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Interlude III - Invisible Accidents'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='All I Do Is Win (feat. T-Pain_ Ludacris_ Snoop Dogg & Rick Ross)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Ironic (Acoustic Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Tiger Feet'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sky Is Falling'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The World Is Not Enough'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Love Letters'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Seven Nation Army (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Bonkers'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Let Her Go'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Poppin' My Collar"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Oh_ George'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Your Woman'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Carte Blanche'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The CD Jokes (LP Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Recado Falado (MetrÃ\x83Â´ Da Saudade)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='My Christmas Tree'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Add to Playlist', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='She'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Isis'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Shots'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Michelle Post'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='PaÃ\x83Â\xads Tropical'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Amanda'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Breathing'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sad Songs (Say So Much)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Take To The Sky'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Soul Survivor'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="What It's Like To Be Me"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Creep (Explicit)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Kryptonite (Radio Edit) (feat. Big Boi)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Incentive (Bonus Track)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sexy Bitch'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Om du var jag'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Stealing Society'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Wild World'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Secret'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Jocko Homo'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sehr kosmisch'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Superstar (featuring Matthew Santos) (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Tomorrow Comes Today'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Northern Skies'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='If She Wants Me'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="He'll Be Around"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Waimea Bay'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Girl'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Soulmate'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Hey_ Soul Sister'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Under The Bridge (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Never Miss A Beat'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Paradise & Dreams'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Debede'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Swing Javanaise'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="I'm Good_ I'm Gone"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Corrido de Boxeo'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Show Me'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Speak'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='El diluvio universal'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Rock & Roll (Album Version)'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Half A Person'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='M79 (Album)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Charmless Man'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Hangnail (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='When You Are Near (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Love Me'),
#  Row(userId='100025', firstname='London', page='Help', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='It Kills Me'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Bye Bye Boyfriend'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Remember yesterday'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Mr. Maker'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Thankful'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Hey_ Soul Sister'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Feelin' Good"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Can't Take My Eyes Off Of You"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Three Times A Lady'),
#  Row(userId='100025', firstname='London', page='Thumbs Down', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Undo'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Pressure [feat. Jay-Z] (Explicit Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Hey_ Soul Sister'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Push (Remastered Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Street Lights'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Diffuse'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='A Te'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Afternoon (Album)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Jetstream'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Deuces Are Wild'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Evil in a closet'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='American Gigolo'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Something In The Air'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='When You Say Nothing At All'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="It's Time I Go (Jazz)"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Hall of Fame'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Go Your Own Way (LP Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Outro'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="That's Just What You Are"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Trinity Dub (Three)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Crown Of Worms (2004 Digital Remaster)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Mental health'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Love to love you baby'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Three Piano Pieces FS131 [Op. 59]: III.     Allegro non troppo'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='We Need Each Other'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Rock The Party (Off The Hook) (2006 Remastered LP Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Face Down (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Control'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Back To The Motor League'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Lately'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="If I Ain't Got You"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Odessa'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Don't Trust The Kids"),
#  Row(userId='100025', firstname='London', page='Settings', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Save Settings', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Settings', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Save Settings', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sad Statue'),
#  Row(userId='100025', firstname='London', page='Logout', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Gloria'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='If You Would Come Back Home'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="It's My Life"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Adagio'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Revelry'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Tight Fit'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sing Swan Song (2004 Digital Remaster)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Ocean And Atlantic (Album)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Welk'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Streets Of New York (City Life)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The Oh Of Pleasure'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Temple Of Love (1992)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Bulls On Parade'),
#  Row(userId='100025', firstname='London', page='Downgrade', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Blurry'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Sugar_ We're Goin Down"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Runnin' Out"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Never Let You Go'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Spaceship'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Fortunate Son'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Times Like These'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Crazy For You No Kisetsu (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='I Love You Always'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Far Away (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Wonder'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Ask Me No Questions'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='El Cartucho'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Back That Azz Up'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Billionaire [feat. Bruno Mars]  (Explicit Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Cuadros Dentro De Cuadros'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='no evil in mind'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='My Immortal'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Love Story'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Head Rolls Off'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Contagious'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Get Your Guns'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Swing Life Away'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Atari Teenage Riot II'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The Gift'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The Old Black Hen'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Spring nicht'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Through The Wire'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Only This Moment  (Live)'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='One Shot (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Rhinemaidens'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='143'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Dolce Infedele'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Heartbeats'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Imanol'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Mil Horas'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Afraid'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='All I Ever Wanted'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Instructions To Sink'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Bestfriend'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='On Top'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Fog'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Summer Nights'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Tive Sim'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Bring Me To Life'),
#  Row(userId='100025', firstname='London', page='Downgrade', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Statue Of A Fool'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Life'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Missing Persons 1 & 2'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Somebody To Love'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='I Just Love You More'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Do You Think I'm Spooky?"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Wot'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Up Up & Away'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Don't Be Shy"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Rockin' The Paradise"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='One Last Breath'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Stationary Stationery'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Super Bon Bon'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Waltz #2 (XO)'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Here Comes That Feeling'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Wild World'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Wishing On A Star'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Le Courage Des Oiseaux'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Why Do I Keep Counting?'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Do It'),
#  Row(userId='100025', firstname='London', page='Downgrade', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Downgrade', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Logout', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Dixie (2006 Remastered LP Version)'),
#  Row(userId='100025', firstname='London', page='Thumbs Down', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Shape Of Things To Come'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Kiedy Rozum Spi'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Whitewash'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The Morning After'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Interlude'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The Only Exception (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Wahid'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Cold As You'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Nic sie nie stalo'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Dead And Gone [feat. Justin Timberlake] (Explicit Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='O Meu Amor Anda Em Fama'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Fireflies'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Samb-Adagio'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Love Of My Life (1993 Digital Remaster)'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Freeze'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='What If I Was White'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Gully Sit'n"),
#  Row(userId='100025', firstname='London', page='Settings', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Settings', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Save Settings', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Pursuit Of Happiness (nightmare)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sehr kosmisch'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Say Yes'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Fuck Kitty'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Te Amo'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Little Dreamer (VÃ\x83Â¤inÃ\x83Â¤mÃ\x83Â¶inen Part II)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Skeleton Boy'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='The Climb'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sin que se note'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='God Gave Me You'),
#  Row(userId='100025', firstname='London', page='Logout', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Settings', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Help', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='My Name Is'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Breathe'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Alejandro'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Use Somebody'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Tighten Up'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Speechless'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Going For My Lungs'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Dance With Me Tonight'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Send Her Back (Album)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="I'm Yours (Album Version)"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Reelin' In The Years"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Love All The Pain Away'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Shadow Feet'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Sarah Wynn'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Van Helsing Boombox'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Secrets'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Breakout A-Town'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Verde Que Te Quero Rosa'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Mistadobalina'),
#  Row(userId='100025', firstname='London', page='About', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='I Kissed A Girl'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Idle Hands (Album)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='A Certain Sadness'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Judge'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Canada'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Complaint Department'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Thin As Clouds'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Settle For Nothing'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Bless Me Indeed (Jabez's Song)"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Fuga N. 1'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Truth Is'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Nearly Home'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Red Staggerwing'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Velouria'),
#  Row(userId='100025', firstname='London', page='Add to Playlist', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Westbound Sign  (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Move Along'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Spiralling'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Savin' Me"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="Sehorns's Farm (LP Version)"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='A Dama Do Sinal'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Kiss With A Fist'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='West One (Shine On Me)'),
#  Row(userId='100025', firstname='London', page='Add to Playlist', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Summer Shudder'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Poison The Hit Parade (Solo)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Quante Volte Ti Ho Cercato'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='I Remember'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Add to Playlist', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Always Where I Need To Be'),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Frances Farmer Will Have Her Revenge On Seattle'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Piano Concerto No. 2 in G minor Op. 22 (2006 Digital Remaster): III.  Presto'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Promise'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song="I'm Ok_ You're Ok"),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Happier'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='I Second That Emotion'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Empty Space'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Whatcha Say'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Birthday'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Cowboy Coffee'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Soil_ Soil (Album Version)'),
#  Row(userId='100025', firstname='London', page='Help', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Superstar (featuring Matthew Santos) (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Slow Death'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='I Believe I Can Fly'),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Valediction'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='paid', song='Blood-Red White & Blue'),
#  Row(userId='100025', firstname='London', page='Downgrade', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Submit Downgrade', level='paid', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="It Wasn't Me"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Under Pressure'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='I Wanna Be Sedated (Remastered Album Version )'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Undo'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Genghis Khan (1998 Digital Remaster)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='My Immortal'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Rosario Tijeras'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Fortunate Fool'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Majestic 12'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Some Kind Of Monster'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Flashlight'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Wave of Mutilation (UK Surf Version)'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='All Star'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="We're All Gonna Die (featuring Iggy Pop)"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Walk Through Hell (featuring Max Bemis Acoustic Exclusive)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Be Mine Tonight'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Love Story'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Let You Know'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Elevator [Feat. Timbaland] (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Pavan & galliard d'Alexandra"),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='True to Myself'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Baby_ I Love Your Way (Album Version)'),
#  Row(userId='100025', firstname='London', page='Add to Playlist', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Far Away (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='There Goes My Baby'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Give It What U Got'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Are You In?'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Liontamer'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Let Me Think About It'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='When You Were Young'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Pomar'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Without Me'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Everything Must Go (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Found Home'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Carolina'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Next Girl'),
#  Row(userId='100025', firstname='London', page='Add Friend', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Add Friend', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Who Wrote Holden Caulfield? (Album version)'),
#  Row(userId='100025', firstname='London', page='Thumbs Down', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Sala De RecepÃ\x83Â§Ã\x83Â£o'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Closer To The Sun'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='The Worst Taste In Music (Extended)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="I'm Not A Loser"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Liebe'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Secrets'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='CafÃ\x83Â© Del Mar'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Professional Party People'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Video Killed The Radio Star'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Warrior's Dance"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Thank Heaven For Little Girls (Live)'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Knuck If You Buck (Allbum Version)'),
#  Row(userId='100025', firstname='London', page='Add to Playlist', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='To Where You Are (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Cry Me A River'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='This Is The Life'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Our Song'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Bored OfHouse'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Watershed (Album Version)'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='This Room'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Don't Cha"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Babylon'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='AMERIKA'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Already Home'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="We Don't Care"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Heavy Water'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Bring Love'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Centerfield'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Every Little Thing She Does Is Magic'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Sic Of Elephants'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Wooden Ships (LP Version)'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Uprising'),
#  Row(userId='100025', firstname='London', page='Thumbs Down', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Inevitable'),
#  Row(userId='100025', firstname='London', page='Thumbs Down', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Airwar'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Effington'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Grind (feat. Moka Only)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Revelry'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Don't Be On With Her"),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Un Misil En Mi Placard'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='You Are So Beautiful'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Friends_ Lovers Or Nothing'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Working With Homesick'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="You're The One"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Someday'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='All I Do Is Win (feat. T-Pain_ Ludacris_ Snoop Dogg & Rick Ross)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Unite (2009 Digital Remaster)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Hero (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Revelry'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Love Letter To Japan'),
#  Row(userId='100025', firstname='London', page='Thumbs Up', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Apple (Album Version)'),
#  Row(userId='100025', firstname='London', page='Logout', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Add Friend', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='The Worm'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Sugar_ We're Goin Down"),
#  Row(userId='100025', firstname='London', page='Add to Playlist', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Ode To A Butterfly'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Island In The Sun'),
#  Row(userId='100025', firstname='London', page='Home', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Bellissima (Video Mix)'),
#  Row(userId='100025', firstname='London', page='Add to Playlist', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='The Beer'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Year of the Suckerpunch'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Up From Below'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Falling Slowly (Album version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Exagerado'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='The Fallen'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Push It'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='You Only Live Once'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='I Never Told You'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Mr. Farmer'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Canada'),
#  Row(userId='100025', firstname='London', page='Thumbs Down', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Can't Stop The Rain (LP Version)"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Walkin' On The Sun"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Obnoxious'),
#  Row(userId='100025', firstname='London', page='Add to Playlist', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Upgrade', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Barcelona'),
#  Row(userId='100025', firstname='London', page='Logout', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Dreamin'"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='You Made Me Like It'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Tenderly'),
#  Row(userId='100025', firstname='London', page='Logout', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Invalid'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Prodigal Son (Harvey's A Star In Your Own Mind Mix)"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Unstoppable'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="You Can't Call Yourself A Secret"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Tryna Make A Jug featuring Big Gee (Amended Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='See You Soon'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Homecoming'),
#  Row(userId='100025', firstname='London', page='Help', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Logout', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Home', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='The Fear'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Prelude 12/21'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="If It's Love"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Pool Party'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Heron Blue'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Mama'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Kings'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='PerdÃ\x83Â³name'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Stronghold Grip'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Lift Your Head Up High (And Blow Your Brains Out)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Pretty Girl'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Window In The Skies'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Lucille'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Calypso War'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Evil Dub'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Rock 'n' Roll"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='I Can Dance'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Der SchÃ\x83Â¶ne und das Biest'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Big Area'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Sugar Ray (LP Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Grand Unification Part 1'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Haze (Album)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Guitar Boogie Shuffle'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='The Hardest Thing'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='The Hand That Holds The World (Medium Key-Premiere Performance Plus w/ Background Vocals)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='No soy yo'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Fiesta Loca'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Chana Masala'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Vuelve'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Them Bones'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Feel It'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='My Doorbell (Album Version)'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Chase the Devil'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Sad Day On Planet Earth'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Big My Secret'),
#  Row(userId='100025', firstname='London', page='Thumbs Down', level='free', song=None),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Pork And Beans'),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song="Antonio's Song (The Rainbow) (Album Version)"),
#  Row(userId='100025', firstname='London', page='NextSong', level='free', song='Highway Song'),
#  Row(userId='100025', firstname='London', page='Roll Advert', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Cancel', level='free', song=None),
#  Row(userId='100025', firstname='London', page='Cancellation Confirmation', level='free', song=None)]

# %% [markdown]
# Define a User-Defined Function (UDF) called `flag_downgrade_event`, which is used to create a binary flag for identifying downgrade events in the dataset.

# %%
flag_downgrade_event = udf(lambda x: 1 if x == "Submit Downgrade" else 0, IntegerType())

# %% [markdown]
# Add a new column called `downgraded` to the `user_log_valid` DataFrame by applying the `flag_downgrade_event` UDF to the `page` column.

# %%
user_log_valid = user_log_valid.withColumn("downgraded", flag_downgrade_event("page"))

# %%
user_log_valid.show(5)
# Out:
# +----------------+---------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-------------+---------+--------------------+------+-------------+--------------------+------+----+----------+
# |          artist|     auth|firstName|gender|itemInSession|lastName|   length|level|            location|method|    page| registration|sessionId|                song|status|           ts|           userAgent|userId|hour|downgraded|
# +----------------+---------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-------------+---------+--------------------+------+-------------+--------------------+------+----+----------+
# |  Martha Tilston|Logged In|    Colin|     M|           50| Freeman|277.89016| paid|     Bakersfield, CA|   PUT|NextSong|1538173362000|       29|           Rockpools|   200|1538352117000|Mozilla/5.0 (Wind...|    30|   0|         0|
# |Five Iron Frenzy|Logged In|    Micah|     M|           79|    Long|236.09424| free|Boston-Cambridge-...|   PUT|NextSong|1538331630000|        8|              Canada|   200|1538352180000|"Mozilla/5.0 (Win...|     9|   0|         0|
# |    Adam Lambert|Logged In|    Colin|     M|           51| Freeman| 282.8273| paid|     Bakersfield, CA|   PUT|NextSong|1538173362000|       29|   Time For Miracles|   200|1538352394000|Mozilla/5.0 (Wind...|    30|   0|         0|
# |          Enigma|Logged In|    Micah|     M|           80|    Long|262.71302| free|Boston-Cambridge-...|   PUT|NextSong|1538331630000|        8|Knocking On Forbi...|   200|1538352416000|"Mozilla/5.0 (Win...|     9|   0|         0|
# |       Daft Punk|Logged In|    Colin|     M|           52| Freeman|223.60771| paid|     Bakersfield, CA|   PUT|NextSong|1538173362000|       29|Harder Better Fas...|   200|1538352676000|Mozilla/5.0 (Wind...|    30|   0|         0|
# +----------------+---------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-------------+---------+--------------------+------+-------------+--------------------+------+----+----------+
# only showing top 5 rows

# %% [markdown]
# Import the `Window` module from PySpark to define window specifications for performing advanced operations, such as cumulative sums, ranking, or aggregations, within partitions of data.
#
# Window functions allow calculations across a subset of rows related to the current row, grouped by specific criteria (e.g., `userId`) and ordered by columns (e.g., timestamps).

# %%
from pyspark.sql import Window

# %% [markdown]
# Define a window specification `windowval` to calculate cumulative metrics for each user (`userId`) based on their activity logs.
#
# **Details:**
#
# 1. **`partitionBy("userId")`**:
#    - Groups rows by `userId`, ensuring calculations are performed independently for each user.
#
# 2. **`orderBy(desc("ts"))`**:
#    - Orders the rows for each user in descending order of the `ts` (timestamp) column, meaning the most recent activity comes first.
#
# 3. **`rangeBetween(Window.unboundedPreceding, 0)`**:
#    - Specifies the range of rows considered for each calculation:
#      - `Window.unboundedPreceding`: Includes all rows from the start of the partition.
#      - `0`: Includes the current row.
#    - Calculation includes all rows up to and including the current row, creating a cumulative effect.

# %%
windowval = Window.partitionBy("userId").orderBy(desc("ts")).rangeBetween(Window.unboundedPreceding, 0)

# %% [markdown]
# Create a new column `phase` by applying a cumulative sum of the `downgraded` column over the defined window.
# This assigns a value of `0` for all rows before the first downgrade event and increments by `1` for each downgrade event, segmenting user activity into distinct phases.
#
# `Fsum` is a PySpark function that computes a cumulative sum over a specified window.
# In this case, it adds up the values in the `downgraded` column, which contains `1` for downgrade events and `0` otherwise. This allows us to track how many downgrades have occurred up to each row, creating a running total within the defined window.

# %%
user_log_valid = user_log_valid.withColumn("phase", Fsum("downgraded").over(windowval))

# %% [markdown]
# Now, if we take, for example, the user with ID `100025`, we will see that their actions are split into those that happened before and after the downgrade event. These actions are also categorized by their account level and the specific pages they visited, giving us a clear timeline of their behavior.

# %%
user_log_valid.select(["userId", "firstname", "ts", "page", "level", "phase"]).where(user_log.userId == "100025").sort("ts", ascending=True).show(800)
# Out:
# [Stage 49:>                                                         (0 + 2) / 2]
# +------+---------+-------------+--------------------+-----+-----+
# |userId|firstname|           ts|                page|level|phase|
# +------+---------+-------------+--------------------+-----+-----+
# |100025|   London|1538397417000|            NextSong| paid|    1|
# |100025|   London|1538397622000|            NextSong| paid|    1|
# |100025|   London|1538397869000|                Home| paid|    1|
# |100025|   London|1538397931000|            NextSong| paid|    1|
# |100025|   London|1538398102000|            NextSong| paid|    1|
# |100025|   London|1538398304000|            NextSong| paid|    1|
# |100025|   London|1538398571000|            NextSong| paid|    1|
# |100025|   London|1538398954000|            NextSong| paid|    1|
# |100025|   London|1538399187000|            NextSong| paid|    1|
# |100025|   London|1538399319000|            NextSong| paid|    1|
# |100025|   London|1538399568000|            NextSong| paid|    1|
# |100025|   London|1538399569000|           Thumbs Up| paid|    1|
# |100025|   London|1538399817000|            NextSong| paid|    1|
# |100025|   London|1538400034000|            NextSong| paid|    1|
# |100025|   London|1538400304000|            NextSong| paid|    1|
# |100025|   London|1538400689000|            NextSong| paid|    1|
# |100025|   London|1538400903000|            NextSong| paid|    1|
# |100025|   London|1538401115000|            NextSong| paid|    1|
# |100025|   London|1538401220000|                Home| paid|    1|
# |100025|   London|1538401613000|            NextSong| paid|    1|
# |100025|   London|1538401850000|            NextSong| paid|    1|
# |100025|   London|1538402156000|            NextSong| paid|    1|
# |100025|   London|1538402382000|            NextSong| paid|    1|
# |100025|   London|1538402846000|            NextSong| paid|    1|
# |100025|   London|1538599994000|            NextSong| paid|    1|
# |100025|   London|1538600286000|                Home| paid|    1|
# |100025|   London|1538600927000|            NextSong| paid|    1|
# |100025|   London|1538601101000|            NextSong| paid|    1|
# |100025|   London|1538601340000|            NextSong| paid|    1|
# |100025|   London|1538601552000|            Settings| paid|    1|
# |100025|   London|1538601962000|            Settings| paid|    1|
# |100025|   London|1538602069000|                Help| paid|    1|
# |100025|   London|1538602132000|            NextSong| paid|    1|
# |100025|   London|1538602347000|            NextSong| paid|    1|
# |100025|   London|1538602348000|           Thumbs Up| paid|    1|
# |100025|   London|1538602569000|            NextSong| paid|    1|
# |100025|   London|1538602815000|            NextSong| paid|    1|
# |100025|   London|1538602832000|               Error| paid|    1|
# |100025|   London|1538603116000|            NextSong| paid|    1|
# |100025|   London|1538603313000|                Home| paid|    1|
# |100025|   London|1538724379000|                Home| paid|    1|
# |100025|   London|1538724497000|            NextSong| paid|    1|
# |100025|   London|1538724744000|            NextSong| paid|    1|
# |100025|   London|1538724788000|            NextSong| paid|    1|
# |100025|   London|1538724989000|            NextSong| paid|    1|
# |100025|   London|1538725193000|            NextSong| paid|    1|
# |100025|   London|1538725367000|            NextSong| paid|    1|
# |100025|   London|1538725567000|            NextSong| paid|    1|
# |100025|   London|1538725822000|            NextSong| paid|    1|
# |100025|   London|1538726014000|            NextSong| paid|    1|
# |100025|   London|1538726219000|            NextSong| paid|    1|
# |100025|   London|1538726446000|            NextSong| paid|    1|
# |100025|   London|1538726703000|            NextSong| paid|    1|
# |100025|   London|1538727000000|            NextSong| paid|    1|
# |100025|   London|1538727296000|            NextSong| paid|    1|
# |100025|   London|1538727593000|            NextSong| paid|    1|
# |100025|   London|1538727844000|            NextSong| paid|    1|
# |100025|   London|1538728157000|            NextSong| paid|    1|
# |100025|   London|1538728158000|           Thumbs Up| paid|    1|
# |100025|   London|1538728384000|            NextSong| paid|    1|
# |100025|   London|1538728516000|            NextSong| paid|    1|
# |100025|   London|1538728749000|            NextSong| paid|    1|
# |100025|   London|1538729099000|            NextSong| paid|    1|
# |100025|   London|1538729264000|            NextSong| paid|    1|
# |100025|   London|1538729605000|            NextSong| paid|    1|
# |100025|   London|1538729725000|            NextSong| paid|    1|
# |100025|   London|1538730003000|            NextSong| paid|    1|
# |100025|   London|1538730212000|            NextSong| paid|    1|
# |100025|   London|1538730763000|            NextSong| paid|    1|
# |100025|   London|1538731095000|            NextSong| paid|    1|
# |100025|   London|1538731325000|            NextSong| paid|    1|
# |100025|   London|1538731575000|            NextSong| paid|    1|
# |100025|   London|1538731628000|            NextSong| paid|    1|
# |100025|   London|1538731855000|            NextSong| paid|    1|
# |100025|   London|1538732091000|            NextSong| paid|    1|
# |100025|   London|1538732320000|            NextSong| paid|    1|
# |100025|   London|1538732491000|            NextSong| paid|    1|
# |100025|   London|1538732492000|           Thumbs Up| paid|    1|
# |100025|   London|1538732726000|            NextSong| paid|    1|
# |100025|   London|1538732918000|            NextSong| paid|    1|
# |100025|   London|1538733149000|            NextSong| paid|    1|
# |100025|   London|1539616057000|            NextSong| paid|    1|
# |100025|   London|1539616479000|                Home| paid|    1|
# |100025|   London|1539616505000|            NextSong| paid|    1|
# |100025|   London|1539616680000|            NextSong| paid|    1|
# |100025|   London|1539616861000|            NextSong| paid|    1|
# |100025|   London|1539617467000|                Home| paid|    1|
# |100025|   London|1539617707000|            NextSong| paid|    1|
# |100025|   London|1539618213000|            NextSong| paid|    1|
# |100025|   London|1539618490000|            NextSong| paid|    1|
# |100025|   London|1539618646000|            NextSong| paid|    1|
# |100025|   London|1539618808000|            NextSong| paid|    1|
# |100025|   London|1539618809000|           Thumbs Up| paid|    1|
# |100025|   London|1539618894000|     Add to Playlist| paid|    1|
# |100025|   London|1539619001000|            NextSong| paid|    1|
# |100025|   London|1539619210000|            NextSong| paid|    1|
# |100025|   London|1539619450000|            NextSong| paid|    1|
# |100025|   London|1539619727000|            NextSong| paid|    1|
# |100025|   London|1539619949000|            NextSong| paid|    1|
# |100025|   London|1539620089000|            NextSong| paid|    1|
# |100025|   London|1539620090000|                Home| paid|    1|
# |100025|   London|1539620338000|            NextSong| paid|    1|
# |100025|   London|1539620593000|            NextSong| paid|    1|
# |100025|   London|1539620858000|            NextSong| paid|    1|
# |100025|   London|1539621107000|            NextSong| paid|    1|
# |100025|   London|1539621335000|            NextSong| paid|    1|
# |100025|   London|1539621615000|            NextSong| paid|    1|
# |100025|   London|1539621785000|            NextSong| paid|    1|
# |100025|   London|1539622020000|            NextSong| paid|    1|
# |100025|   London|1539622262000|            NextSong| paid|    1|
# |100025|   London|1539622516000|            NextSong| paid|    1|
# |100025|   London|1539622737000|            NextSong| paid|    1|
# |100025|   London|1539622985000|            NextSong| paid|    1|
# |100025|   London|1539623162000|            NextSong| paid|    1|
# |100025|   London|1539623362000|            NextSong| paid|    1|
# |100025|   London|1539623656000|            NextSong| paid|    1|
# |100025|   London|1539623875000|            NextSong| paid|    1|
# |100025|   London|1539624091000|                Home| paid|    1|
# |100025|   London|1539624530000|            NextSong| paid|    1|
# |100025|   London|1539624818000|            NextSong| paid|    1|
# |100025|   London|1539625010000|            NextSong| paid|    1|
# |100025|   London|1539625545000|            NextSong| paid|    1|
# |100025|   London|1539625850000|            NextSong| paid|    1|
# |100025|   London|1539626079000|            NextSong| paid|    1|
# |100025|   London|1539626245000|            NextSong| paid|    1|
# |100025|   London|1539626456000|            NextSong| paid|    1|
# |100025|   London|1539626668000|            NextSong| paid|    1|
# |100025|   London|1539626884000|            NextSong| paid|    1|
# |100025|   London|1539627149000|            NextSong| paid|    1|
# |100025|   London|1539627336000|            NextSong| paid|    1|
# |100025|   London|1539627579000|            NextSong| paid|    1|
# |100025|   London|1539627751000|            NextSong| paid|    1|
# |100025|   London|1539627997000|            NextSong| paid|    1|
# |100025|   London|1539628186000|            NextSong| paid|    1|
# |100025|   London|1539628387000|            NextSong| paid|    1|
# |100025|   London|1539628654000|            NextSong| paid|    1|
# |100025|   London|1539628889000|            NextSong| paid|    1|
# |100025|   London|1539629137000|            NextSong| paid|    1|
# |100025|   London|1539629138000|           Thumbs Up| paid|    1|
# |100025|   London|1539629375000|            NextSong| paid|    1|
# |100025|   London|1539629592000|            NextSong| paid|    1|
# |100025|   London|1539629847000|            NextSong| paid|    1|
# |100025|   London|1539630062000|            NextSong| paid|    1|
# |100025|   London|1539630296000|            NextSong| paid|    1|
# |100025|   London|1539630537000|            NextSong| paid|    1|
# |100025|   London|1539630707000|                Help| paid|    1|
# |100025|   London|1539630728000|            NextSong| paid|    1|
# |100025|   London|1539630978000|            NextSong| paid|    1|
# |100025|   London|1539631232000|            NextSong| paid|    1|
# |100025|   London|1539631559000|            NextSong| paid|    1|
# |100025|   London|1539631738000|            NextSong| paid|    1|
# |100025|   London|1539631982000|            NextSong| paid|    1|
# |100025|   London|1539632198000|            NextSong| paid|    1|
# |100025|   London|1539632456000|            NextSong| paid|    1|
# |100025|   London|1539632677000|            NextSong| paid|    1|
# |100025|   London|1539632678000|         Thumbs Down| paid|    1|
# |100025|   London|1539632896000|            NextSong| paid|    1|
# |100025|   London|1539633244000|            NextSong| paid|    1|
# |100025|   London|1539633531000|            NextSong| paid|    1|
# |100025|   London|1539633747000|            NextSong| paid|    1|
# |100025|   London|1539633984000|            NextSong| paid|    1|
# |100025|   London|1539634173000|            NextSong| paid|    1|
# |100025|   London|1539634447000|            NextSong| paid|    1|
# |100025|   London|1539634641000|                Home| paid|    1|
# |100025|   London|1539634711000|            NextSong| paid|    1|
# |100025|   London|1539634838000|            NextSong| paid|    1|
# |100025|   London|1539635231000|            NextSong| paid|    1|
# |100025|   London|1539635443000|            NextSong| paid|    1|
# |100025|   London|1539635685000|            NextSong| paid|    1|
# |100025|   London|1539635846000|            NextSong| paid|    1|
# |100025|   London|1539636080000|            NextSong| paid|    1|
# |100025|   London|1539636340000|            NextSong| paid|    1|
# |100025|   London|1539636588000|            NextSong| paid|    1|
# |100025|   London|1539636741000|            NextSong| paid|    1|
# |100025|   London|1539636956000|            NextSong| paid|    1|
# |100025|   London|1539637468000|            NextSong| paid|    1|
# |100025|   London|1539637733000|            NextSong| paid|    1|
# |100025|   London|1539637914000|            NextSong| paid|    1|
# |100025|   London|1539638176000|            NextSong| paid|    1|
# |100025|   London|1539638372000|            NextSong| paid|    1|
# |100025|   London|1539821009000|                Home| paid|    1|
# |100025|   London|1539821098000|            NextSong| paid|    1|
# |100025|   London|1539821311000|            NextSong| paid|    1|
# |100025|   London|1539821312000|           Thumbs Up| paid|    1|
# |100025|   London|1539821600000|            NextSong| paid|    1|
# |100025|   London|1539821855000|            NextSong| paid|    1|
# |100025|   London|1539822061000|            NextSong| paid|    1|
# |100025|   London|1539822252000|            NextSong| paid|    1|
# |100025|   London|1539822402000|            NextSong| paid|    1|
# |100025|   London|1539822562000|            NextSong| paid|    1|
# |100025|   London|1539822665000|            NextSong| paid|    1|
# |100025|   London|1539822894000|            NextSong| paid|    1|
# |100025|   London|1539823209000|            NextSong| paid|    1|
# |100025|   London|1539823500000|            Settings| paid|    1|
# |100025|   London|1539823501000|       Save Settings| paid|    1|
# |100025|   London|1539823550000|                Home| paid|    1|
# |100025|   London|1539823563000|            Settings| paid|    1|
# |100025|   London|1539823564000|       Save Settings| paid|    1|
# |100025|   London|1539922927000|                Home| paid|    1|
# |100025|   London|1539923762000|            NextSong| paid|    1|
# |100025|   London|1539923763000|              Logout| paid|    1|
# |100025|   London|1539924248000|                Home| paid|    1|
# |100025|   London|1539924324000|            NextSong| paid|    1|
# |100025|   London|1539924683000|            NextSong| paid|    1|
# |100025|   London|1539924914000|            NextSong| paid|    1|
# |100025|   London|1539925138000|            NextSong| paid|    1|
# |100025|   London|1539925451000|            NextSong| paid|    1|
# |100025|   London|1539925652000|            NextSong| paid|    1|
# |100025|   London|1539925653000|           Thumbs Up| paid|    1|
# |100025|   London|1539925887000|            NextSong| paid|    1|
# |100025|   London|1539926174000|            NextSong| paid|    1|
# |100025|   London|1539926384000|            NextSong| paid|    1|
# |100025|   London|1539926762000|            NextSong| paid|    1|
# |100025|   London|1539927217000|            NextSong| paid|    1|
# |100025|   London|1539927539000|            NextSong| paid|    1|
# |100025|   London|1539928026000|            NextSong| paid|    1|
# |100025|   London|1539928455000|           Downgrade| paid|    1|
# |100025|   London|1539928655000|            NextSong| paid|    1|
# |100025|   London|1539928958000|            NextSong| paid|    1|
# |100025|   London|1539929175000|            NextSong| paid|    1|
# |100025|   London|1539929407000|            NextSong| paid|    1|
# |100025|   London|1539929671000|            NextSong| paid|    1|
# |100025|   London|1539929995000|            NextSong| paid|    1|
# |100025|   London|1539930133000|            NextSong| paid|    1|
# |100025|   London|1539930274000|            NextSong| paid|    1|
# |100025|   London|1539930535000|            NextSong| paid|    1|
# |100025|   London|1539930865000|            NextSong| paid|    1|
# |100025|   London|1539931103000|            NextSong| paid|    1|
# |100025|   London|1539931324000|            NextSong| paid|    1|
# |100025|   London|1539931537000|            NextSong| paid|    1|
# |100025|   London|1539931729000|            NextSong| paid|    1|
# |100025|   London|1539931994000|            NextSong| paid|    1|
# |100025|   London|1539932205000|            NextSong| paid|    1|
# |100025|   London|1539932386000|            NextSong| paid|    1|
# |100025|   London|1539932624000|            NextSong| paid|    1|
# |100025|   London|1539932886000|            NextSong| paid|    1|
# |100025|   London|1539933119000|            NextSong| paid|    1|
# |100025|   London|1539933342000|            NextSong| paid|    1|
# |100025|   London|1539933690000|            NextSong| paid|    1|
# |100025|   London|1539933904000|            NextSong| paid|    1|
# |100025|   London|1539934104000|            NextSong| paid|    1|
# |100025|   London|1539934473000|            NextSong| paid|    1|
# |100025|   London|1539934775000|            NextSong| paid|    1|
# |100025|   London|1539935123000|            NextSong| paid|    1|
# |100025|   London|1539935371000|            NextSong| paid|    1|
# |100025|   London|1539935649000|            NextSong| paid|    1|
# |100025|   London|1539935650000|           Thumbs Up| paid|    1|
# |100025|   London|1539935893000|            NextSong| paid|    1|
# |100025|   London|1539936114000|            NextSong| paid|    1|
# |100025|   London|1539936365000|            NextSong| paid|    1|
# |100025|   London|1539936662000|            NextSong| paid|    1|
# |100025|   London|1539936841000|            NextSong| paid|    1|
# |100025|   London|1539936999000|            NextSong| paid|    1|
# |100025|   London|1539937132000|            NextSong| paid|    1|
# |100025|   London|1539937299000|            NextSong| paid|    1|
# |100025|   London|1539937384000|         Roll Advert| paid|    1|
# |100025|   London|1539937492000|            NextSong| paid|    1|
# |100025|   London|1539937737000|            NextSong| paid|    1|
# |100025|   London|1539937893000|            NextSong| paid|    1|
# |100025|   London|1539938158000|            NextSong| paid|    1|
# |100025|   London|1539938416000|            NextSong| paid|    1|
# |100025|   London|1539938661000|            NextSong| paid|    1|
# |100025|   London|1539938811000|         Roll Advert| paid|    1|
# |100025|   London|1539938875000|            NextSong| paid|    1|
# |100025|   London|1539939002000|            NextSong| paid|    1|
# |100025|   London|1539939105000|           Downgrade| paid|    1|
# |100025|   London|1539939408000|                Home| paid|    1|
# |100025|   London|1539939504000|            NextSong| paid|    1|
# |100025|   London|1539939675000|            NextSong| paid|    1|
# |100025|   London|1539939857000|            NextSong| paid|    1|
# |100025|   London|1539940156000|            NextSong| paid|    1|
# |100025|   London|1539940157000|           Thumbs Up| paid|    1|
# |100025|   London|1539940376000|            NextSong| paid|    1|
# |100025|   London|1539940561000|            NextSong| paid|    1|
# |100025|   London|1539940960000|            NextSong| paid|    1|
# |100025|   London|1539941298000|            NextSong| paid|    1|
# |100025|   London|1539941525000|            NextSong| paid|    1|
# |100025|   London|1539941708000|            NextSong| paid|    1|
# |100025|   London|1539941923000|            NextSong| paid|    1|
# |100025|   London|1539942161000|            NextSong| paid|    1|
# |100025|   London|1539942215000|                Home| paid|    1|
# |100025|   London|1539942233000|                Home| paid|    1|
# |100025|   London|1539942339000|            NextSong| paid|    1|
# |100025|   London|1539942550000|            NextSong| paid|    1|
# |100025|   London|1539942551000|           Thumbs Up| paid|    1|
# |100025|   London|1539942830000|            NextSong| paid|    1|
# |100025|   London|1539942954000|            NextSong| paid|    1|
# |100025|   London|1539943154000|            NextSong| paid|    1|
# |100025|   London|1539943453000|            NextSong| paid|    1|
# |100025|   London|1539943606000|            NextSong| paid|    1|
# |100025|   London|1539943870000|            NextSong| paid|    1|
# |100025|   London|1539943902000|           Downgrade| paid|    1|
# |100025|   London|1539943993000|           Downgrade| paid|    1|
# |100025|   London|1539943994000|              Logout| paid|    1|
# |100025|   London|1539944204000|                Home| paid|    1|
# |100025|   London|1539944235000|            NextSong| paid|    1|
# |100025|   London|1539944236000|         Thumbs Down| paid|    1|
# |100025|   London|1539944455000|            NextSong| paid|    1|
# |100025|   London|1539944729000|            NextSong| paid|    1|
# |100025|   London|1539945041000|            NextSong| paid|    1|
# |100025|   London|1539945323000|            NextSong| paid|    1|
# |100025|   London|1539945585000|            NextSong| paid|    1|
# |100025|   London|1539945622000|            NextSong| paid|    1|
# |100025|   London|1539945889000|            NextSong| paid|    1|
# |100025|   London|1539945988000|            NextSong| paid|    1|
# |100025|   London|1539946238000|            NextSong| paid|    1|
# |100025|   London|1539946440000|            NextSong| paid|    1|
# |100025|   London|1539946739000|            NextSong| paid|    1|
# |100025|   London|1539946869000|            NextSong| paid|    1|
# |100025|   London|1539947094000|            NextSong| paid|    1|
# |100025|   London|1539947451000|            NextSong| paid|    1|
# |100025|   London|1539947725000|         Roll Advert| paid|    1|
# |100025|   London|1539947782000|         Roll Advert| paid|    1|
# |100025|   London|1539947804000|         Roll Advert| paid|    1|
# |100025|   London|1539948058000|            NextSong| paid|    1|
# |100025|   London|1539948292000|            NextSong| paid|    1|
# |100025|   London|1539948574000|            NextSong| paid|    1|
# |100025|   London|1539948900000|            Settings| paid|    1|
# |100025|   London|1539949073000|            Settings| paid|    1|
# |100025|   London|1539949074000|       Save Settings| paid|    1|
# |100025|   London|1539949221000|                Home| paid|    1|
# |100025|   London|1539949871000|            NextSong| paid|    1|
# |100025|   London|1539950166000|            NextSong| paid|    1|
# |100025|   London|1539950821000|            NextSong| paid|    1|
# |100025|   London|1539950959000|            NextSong| paid|    1|
# |100025|   London|1539951093000|            NextSong| paid|    1|
# |100025|   London|1539951301000|            NextSong| paid|    1|
# |100025|   London|1539951621000|            NextSong| paid|    1|
# |100025|   London|1539951834000|            NextSong| paid|    1|
# |100025|   London|1539952070000|            NextSong| paid|    1|
# |100025|   London|1539952336000|            NextSong| paid|    1|
# |100025|   London|1539952337000|              Logout| paid|    1|
# |100025|   London|1539952724000|                Home| paid|    1|
# |100025|   London|1539952739000|            Settings| paid|    1|
# |100025|   London|1539952748000|                Help| paid|    1|
# |100025|   London|1539952840000|            NextSong| paid|    1|
# |100025|   London|1539952840000|         Roll Advert| paid|    1|
# |100025|   London|1539953109000|            NextSong| paid|    1|
# |100025|   London|1539953409000|            NextSong| paid|    1|
# |100025|   London|1539953683000|            NextSong| paid|    1|
# |100025|   London|1539953914000|            NextSong| paid|    1|
# |100025|   London|1539954125000|            NextSong| paid|    1|
# |100025|   London|1539954395000|            NextSong| paid|    1|
# |100025|   London|1539954602000|            NextSong| paid|    1|
# |100025|   London|1539954727000|            NextSong| paid|    1|
# |100025|   London|1539954905000|            NextSong| paid|    1|
# |100025|   London|1539955148000|            NextSong| paid|    1|
# |100025|   London|1539955421000|            NextSong| paid|    1|
# |100025|   London|1539955642000|            NextSong| paid|    1|
# |100025|   London|1539955859000|            NextSong| paid|    1|
# |100025|   London|1539956063000|            NextSong| paid|    1|
# |100025|   London|1539956285000|            NextSong| paid|    1|
# |100025|   London|1539956509000|            NextSong| paid|    1|
# |100025|   London|1539956651000|            NextSong| paid|    1|
# |100025|   London|1539956839000|            NextSong| paid|    1|
# |100025|   London|1539956861000|               About| paid|    1|
# |100025|   London|1539957096000|            NextSong| paid|    1|
# |100025|   London|1539957275000|            NextSong| paid|    1|
# |100025|   London|1539957552000|            NextSong| paid|    1|
# |100025|   London|1539957552000|         Roll Advert| paid|    1|
# |100025|   London|1539958130000|         Roll Advert| paid|    1|
# |100025|   London|1539958214000|            NextSong| paid|    1|
# |100025|   London|1539958414000|            NextSong| paid|    1|
# |100025|   London|1539958650000|            NextSong| paid|    1|
# |100025|   London|1539958922000|            NextSong| paid|    1|
# |100025|   London|1539959172000|            NextSong| paid|    1|
# |100025|   London|1539959460000|            NextSong| paid|    1|
# |100025|   London|1539959714000|            NextSong| paid|    1|
# |100025|   London|1539960116000|            NextSong| paid|    1|
# |100025|   London|1539960117000|           Thumbs Up| paid|    1|
# |100025|   London|1539960376000|            NextSong| paid|    1|
# |100025|   London|1539960707000|            NextSong| paid|    1|
# |100025|   London|1539960887000|            NextSong| paid|    1|
# |100025|   London|1539961194000|     Add to Playlist| paid|    1|
# |100025|   London|1539961204000|            NextSong| paid|    1|
# |100025|   London|1539961337000|            NextSong| paid|    1|
# |100025|   London|1539961575000|            NextSong| paid|    1|
# |100025|   London|1539961840000|            NextSong| paid|    1|
# |100025|   London|1539962057000|            NextSong| paid|    1|
# |100025|   London|1539962208000|            NextSong| paid|    1|
# |100025|   London|1539962402000|            NextSong| paid|    1|
# |100025|   London|1539962533000|            NextSong| paid|    1|
# |100025|   London|1539963170000|     Add to Playlist| paid|    1|
# |100025|   London|1539963225000|            NextSong| paid|    1|
# |100025|   London|1539963292000|                Home| paid|    1|
# |100025|   London|1539963412000|            NextSong| paid|    1|
# |100025|   London|1539963638000|            NextSong| paid|    1|
# |100025|   London|1539963944000|            NextSong| paid|    1|
# |100025|   London|1539963945000|           Thumbs Up| paid|    1|
# |100025|   London|1539964070000|     Add to Playlist| paid|    1|
# |100025|   London|1539964205000|            NextSong| paid|    1|
# |100025|   London|1539964226000|                Home| paid|    1|
# |100025|   London|1539964364000|            NextSong| paid|    1|
# |100025|   London|1539964613000|            NextSong| paid|    1|
# |100025|   London|1539964988000|            NextSong| paid|    1|
# |100025|   London|1539965211000|            NextSong| paid|    1|
# |100025|   London|1539965370000|            NextSong| paid|    1|
# |100025|   London|1539965578000|            NextSong| paid|    1|
# |100025|   London|1539965746000|            NextSong| paid|    1|
# |100025|   London|1539966047000|            NextSong| paid|    1|
# |100025|   London|1539966269000|            NextSong| paid|    1|
# |100025|   London|1539966496000|            NextSong| paid|    1|
# |100025|   London|1539966611000|            NextSong| paid|    1|
# |100025|   London|1539966837000|                Help| paid|    1|
# |100025|   London|1539967065000|                Home| paid|    1|
# |100025|   London|1539967616000|            NextSong| paid|    1|
# |100025|   London|1539967904000|            NextSong| paid|    1|
# |100025|   London|1539968203000|            NextSong| paid|    1|
# |100025|   London|1539968522000|            NextSong| paid|    1|
# |100025|   London|1539968523000|           Thumbs Up| paid|    1|
# |100025|   London|1539968643000|            NextSong| paid|    1|
# |100025|   London|1539968727000|           Downgrade| paid|    1|
# |100025|   London|1539968728000|    Submit Downgrade| paid|    1|
# |100025|   London|1539968742000|                Home| free|    0|
# |100025|   London|1539968862000|            NextSong| free|    0|
# |100025|   London|1539969088000|            NextSong| free|    0|
# |100025|   London|1539969089000|           Thumbs Up| free|    0|
# |100025|   London|1539969315000|            NextSong| free|    0|
# |100025|   London|1539969464000|            NextSong| free|    0|
# |100025|   London|1539969812000|            NextSong| free|    0|
# |100025|   London|1539970000000|            NextSong| free|    0|
# |100025|   London|1539970262000|            NextSong| free|    0|
# |100025|   London|1539970469000|            NextSong| free|    0|
# |100025|   London|1539970697000|            NextSong| free|    0|
# |100025|   London|1539971006000|            NextSong| free|    0|
# |100025|   London|1539971007000|           Thumbs Up| free|    0|
# |100025|   London|1539971511000|            NextSong| free|    0|
# |100025|   London|1539971679000|         Roll Advert| free|    0|
# |100025|   London|1539971946000|            NextSong| free|    0|
# |100025|   London|1539972027000|         Roll Advert| free|    0|
# |100025|   London|1539972127000|            NextSong| free|    0|
# |100025|   London|1539972326000|            NextSong| free|    0|
# |100025|   London|1539972598000|            NextSong| free|    0|
# |100025|   London|1539972806000|            NextSong| free|    0|
# |100025|   London|1539972990000|            NextSong| free|    0|
# |100025|   London|1539973224000|         Roll Advert| free|    0|
# |100025|   London|1539973252000|            NextSong| free|    0|
# |100025|   London|1539973685000|         Roll Advert| free|    0|
# |100025|   London|1539973790000|            NextSong| free|    0|
# |100025|   London|1539974020000|            NextSong| free|    0|
# |100025|   London|1539974291000|         Roll Advert| free|    0|
# |100025|   London|1539974607000|            NextSong| free|    0|
# |100025|   London|1539974907000|            NextSong| free|    0|
# |100025|   London|1539975132000|     Add to Playlist| free|    0|
# |100025|   London|1539975156000|            NextSong| free|    0|
# |100025|   London|1539975394000|            NextSong| free|    0|
# |100025|   London|1539975675000|            NextSong| free|    0|
# |100025|   London|1539975935000|            NextSong| free|    0|
# |100025|   London|1539976198000|            NextSong| free|    0|
# |100025|   London|1539976547000|            NextSong| free|    0|
# |100025|   London|1539976612000|         Roll Advert| free|    0|
# |100025|   London|1539976697000|            NextSong| free|    0|
# |100025|   London|1539976917000|            NextSong| free|    0|
# |100025|   London|1539977231000|            NextSong| free|    0|
# |100025|   London|1539977482000|            NextSong| free|    0|
# |100025|   London|1539977766000|            NextSong| free|    0|
# |100025|   London|1539977910000|            NextSong| free|    0|
# |100025|   London|1539978188000|            NextSong| free|    0|
# |100025|   London|1539978189000|          Add Friend| free|    0|
# |100025|   London|1539978190000|          Add Friend| free|    0|
# |100025|   London|1539978386000|            NextSong| free|    0|
# |100025|   London|1539978387000|         Thumbs Down| free|    0|
# |100025|   London|1539978550000|            NextSong| free|    0|
# |100025|   London|1539978551000|           Thumbs Up| free|    0|
# |100025|   London|1539978758000|            NextSong| free|    0|
# |100025|   London|1539978909000|            NextSong| free|    0|
# |100025|   London|1539979102000|            NextSong| free|    0|
# |100025|   London|1539979191000|            NextSong| free|    0|
# |100025|   London|1539979419000|            NextSong| free|    0|
# |100025|   London|1539979643000|            NextSong| free|    0|
# |100025|   London|1539980105000|            NextSong| free|    0|
# |100025|   London|1539980293000|            NextSong| free|    0|
# |100025|   London|1539980491000|            NextSong| free|    0|
# |100025|   London|1539980803000|            NextSong| free|    0|
# |100025|   London|1539980896000|         Roll Advert| free|    0|
# |100025|   London|1539980911000|            NextSong| free|    0|
# |100025|   London|1539981051000|     Add to Playlist| free|    0|
# |100025|   London|1539981116000|            NextSong| free|    0|
# |100025|   London|1539981349000|            NextSong| free|    0|
# |100025|   London|1539981637000|            NextSong| free|    0|
# |100025|   London|1539981846000|            NextSong| free|    0|
# |100025|   London|1539982047000|            NextSong| free|    0|
# |100025|   London|1539982625000|            NextSong| free|    0|
# |100025|   London|1539982626000|           Thumbs Up| free|    0|
# |100025|   London|1539982781000|            NextSong| free|    0|
# |100025|   London|1539983081000|            NextSong| free|    0|
# |100025|   London|1539983353000|            NextSong| free|    0|
# |100025|   London|1539983658000|            NextSong| free|    0|
# |100025|   London|1539983884000|            NextSong| free|    0|
# |100025|   London|1539983885000|           Thumbs Up| free|    0|
# |100025|   London|1539984154000|            NextSong| free|    0|
# |100025|   London|1539984396000|            NextSong| free|    0|
# |100025|   London|1539984668000|            NextSong| free|    0|
# |100025|   London|1539984890000|            NextSong| free|    0|
# |100025|   London|1539985121000|            NextSong| free|    0|
# |100025|   London|1539985514000|         Roll Advert| free|    0|
# |100025|   London|1539985623000|            NextSong| free|    0|
# |100025|   London|1539985909000|            NextSong| free|    0|
# |100025|   London|1539986313000|         Roll Advert| free|    0|
# |100025|   London|1539987035000|            NextSong| free|    0|
# |100025|   London|1539987036000|         Thumbs Down| free|    0|
# |100025|   London|1539987339000|            NextSong| free|    0|
# |100025|   London|1539987340000|         Thumbs Down| free|    0|
# |100025|   London|1539987566000|            NextSong| free|    0|
# |100025|   London|1539987969000|         Roll Advert| free|    0|
# |100025|   London|1539988168000|            NextSong| free|    0|
# |100025|   London|1539988372000|            NextSong| free|    0|
# |100025|   London|1539988566000|            NextSong| free|    0|
# |100025|   London|1539988767000|            NextSong| free|    0|
# |100025|   London|1539989251000|         Roll Advert| free|    0|
# |100025|   London|1539989325000|            NextSong| free|    0|
# |100025|   London|1539989618000|         Roll Advert| free|    0|
# |100025|   London|1539989715000|            NextSong| free|    0|
# |100025|   London|1539989882000|            NextSong| free|    0|
# |100025|   London|1539990357000|         Roll Advert| free|    0|
# |100025|   London|1539990361000|            NextSong| free|    0|
# |100025|   London|1539990560000|            NextSong| free|    0|
# |100025|   London|1539990799000|            NextSong| free|    0|
# |100025|   London|1539991006000|            NextSong| free|    0|
# |100025|   London|1539991233000|            NextSong| free|    0|
# |100025|   London|1539991444000|            NextSong| free|    0|
# |100025|   London|1539991630000|            NextSong| free|    0|
# |100025|   London|1539991648000|         Roll Advert| free|    0|
# |100025|   London|1539991831000|            NextSong| free|    0|
# |100025|   London|1539991832000|           Thumbs Up| free|    0|
# |100025|   London|1539992077000|            NextSong| free|    0|
# |100025|   London|1539992078000|              Logout| free|    0|
# |100025|   London|1539992595000|                Home| free|    0|
# |100025|   London|1539992596000|          Add Friend| free|    0|
# |100025|   London|1539992612000|                Home| free|    0|
# |100025|   London|1539993201000|            NextSong| free|    0|
# |100025|   London|1539993437000|            NextSong| free|    0|
# |100025|   London|1539993636000|     Add to Playlist| free|    0|
# |100025|   London|1539993654000|            NextSong| free|    0|
# |100025|   London|1539993902000|            NextSong| free|    0|
# |100025|   London|1539994024000|                Home| free|    0|
# |100025|   London|1539994101000|            NextSong| free|    0|
# |100025|   London|1539994201000|     Add to Playlist| free|    0|
# |100025|   London|1539994331000|            NextSong| free|    0|
# |100025|   London|1539994522000|            NextSong| free|    0|
# |100025|   London|1539994826000|            NextSong| free|    0|
# |100025|   London|1539995011000|         Roll Advert| free|    0|
# |100025|   London|1539995076000|            NextSong| free|    0|
# |100025|   London|1539995366000|            NextSong| free|    0|
# |100025|   London|1539995659000|            NextSong| free|    0|
# |100025|   London|1539995896000|            NextSong| free|    0|
# |100025|   London|1539996137000|            NextSong| free|    0|
# |100025|   London|1539996172000|         Roll Advert| free|    0|
# |100025|   London|1539996328000|            NextSong| free|    0|
# |100025|   London|1539996561000|            NextSong| free|    0|
# |100025|   London|1539996735000|            NextSong| free|    0|
# |100025|   London|1539996736000|         Thumbs Down| free|    0|
# |100025|   London|1539996971000|            NextSong| free|    0|
# |100025|   London|1539997187000|            NextSong| free|    0|
# |100025|   London|1539997393000|            NextSong| free|    0|
# |100025|   London|1539997470000|     Add to Playlist| free|    0|
# |100025|   London|1539997684000|             Upgrade| free|    0|
# |100025|   London|1539997690000|                Home| free|    0|
# |100025|   London|1539997756000|            NextSong| free|    0|
# |100025|   London|1539997757000|              Logout| free|    0|
# |100025|   London|1539998211000|                Home| free|    0|
# |100025|   London|1539998508000|            NextSong| free|    0|
# |100025|   London|1539998819000|            NextSong| free|    0|
# |100025|   London|1539999011000|            NextSong| free|    0|
# |100025|   London|1539999012000|              Logout| free|    0|
# |100025|   London|1539999305000|                Home| free|    0|
# |100025|   London|1539999427000|            NextSong| free|    0|
# |100025|   London|1539999660000|            NextSong| free|    0|
# |100025|   London|1540000266000|            NextSong| free|    0|
# |100025|   London|1540000478000|            NextSong| free|    0|
# |100025|   London|1540000720000|            NextSong| free|    0|
# |100025|   London|1540000970000|            NextSong| free|    0|
# |100025|   London|1540001141000|            NextSong| free|    0|
# |100025|   London|1540001270000|                Help| free|    0|
# |100025|   London|1540001271000|              Logout| free|    0|
# |100025|   London|1540289015000|                Home| free|    0|
# |100025|   London|1540289059000|            NextSong| free|    0|
# |100025|   London|1540289073000|         Roll Advert| free|    0|
# |100025|   London|1540289265000|            NextSong| free|    0|
# |100025|   London|1540289359000|            NextSong| free|    0|
# |100025|   London|1540289598000|            NextSong| free|    0|
# |100025|   London|1540289853000|            NextSong| free|    0|
# |100025|   London|1540290310000|            NextSong| free|    0|
# |100025|   London|1540290613000|            NextSong| free|    0|
# |100025|   London|1540290627000|         Roll Advert| free|    0|
# |100025|   London|1540290838000|            NextSong| free|    0|
# |100025|   London|1540291178000|            NextSong| free|    0|
# |100025|   London|1540291425000|            NextSong| free|    0|
# |100025|   London|1540291723000|            NextSong| free|    0|
# |100025|   London|1540292000000|            NextSong| free|    0|
# |100025|   London|1540292247000|            NextSong| free|    0|
# |100025|   London|1540292466000|            NextSong| free|    0|
# |100025|   London|1540292603000|            NextSong| free|    0|
# |100025|   London|1540292967000|            NextSong| free|    0|
# |100025|   London|1540293150000|            NextSong| free|    0|
# |100025|   London|1540293265000|            NextSong| free|    0|
# |100025|   London|1540293531000|            NextSong| free|    0|
# |100025|   London|1540293818000|            NextSong| free|    0|
# |100025|   London|1540293944000|            NextSong| free|    0|
# |100025|   London|1540294140000|            NextSong| free|    0|
# |100025|   London|1540294708000|            NextSong| free|    0|
# |100025|   London|1540295130000|         Roll Advert| free|    0|
# |100025|   London|1540295174000|         Roll Advert| free|    0|
# |100025|   London|1540295263000|            NextSong| free|    0|
# |100025|   London|1540295537000|            NextSong| free|    0|
# |100025|   London|1540295810000|            NextSong| free|    0|
# |100025|   London|1540296038000|            NextSong| free|    0|
# |100025|   London|1540296409000|            NextSong| free|    0|
# |100025|   London|1540296653000|            NextSong| free|    0|
# |100025|   London|1540296962000|            NextSong| free|    0|
# |100025|   London|1540297111000|            NextSong| free|    0|
# |100025|   London|1540297352000|            NextSong| free|    0|
# |100025|   London|1540297593000|            NextSong| free|    0|
# |100025|   London|1540297717000|         Roll Advert| free|    0|
# |100025|   London|1540297776000|            NextSong| free|    0|
# |100025|   London|1540298109000|            NextSong| free|    0|
# |100025|   London|1540298110000|         Thumbs Down| free|    0|
# |100025|   London|1540298282000|            NextSong| free|    0|
# |100025|   London|1540298471000|            NextSong| free|    0|
# |100025|   London|1540298776000|            NextSong| free|    0|
# |100025|   London|1540298978000|         Roll Advert| free|    0|
# |100025|   London|1540298979000|              Cancel| free|    0|
# |100025|   London|1540299152000|Cancellation Conf...| free|    0|
# +------+---------+-------------+--------------------+-----+-----+

# %% [markdown]
# Now we also see that there are some users with a `phase` value equal to `2`, which means they have downgraded their account twice. This allows us to track their behavior across multiple transitions, examining their actions before and after each downgrade event to understand their engagement and account activity patterns over time.

# %%
user_log_valid.select(["userId", "firstname", "ts", "page", "level", "phase"]).where(user_log.userId == "100004").sort("ts", ascending=True).show(800)
# Out:
# [Stage 52:>                                                         (0 + 2) / 2]
# +------+---------+-------------+----------------+-----+-----+
# |userId|firstname|           ts|            page|level|phase|
# +------+---------+-------------+----------------+-----+-----+
# |100004|    Emily|1538534835000|            Home| free|    2|
# |100004|    Emily|1538534867000|        NextSong| free|    2|
# |100004|    Emily|1538534975000|        NextSong| free|    2|
# |100004|    Emily|1538535013000|        NextSong| free|    2|
# |100004|    Emily|1538535232000|        NextSong| free|    2|
# |100004|    Emily|1538535414000|        NextSong| free|    2|
# |100004|    Emily|1538535792000|        NextSong| free|    2|
# |100004|    Emily|1538536045000|        NextSong| free|    2|
# |100004|    Emily|1538536211000|     Roll Advert| free|    2|
# |100004|    Emily|1538536381000|        NextSong| free|    2|
# |100004|    Emily|1538536609000|        NextSong| free|    2|
# |100004|    Emily|1538536828000|        NextSong| free|    2|
# |100004|    Emily|1538536911000|        Settings| free|    2|
# |100004|    Emily|1538536912000|   Save Settings| free|    2|
# |100004|    Emily|1538537021000|            Home| free|    2|
# |100004|    Emily|1538537047000|        NextSong| free|    2|
# |100004|    Emily|1538537310000|        NextSong| free|    2|
# |100004|    Emily|1538537514000|        NextSong| free|    2|
# |100004|    Emily|1538537796000|        NextSong| free|    2|
# |100004|    Emily|1538538246000|        NextSong| free|    2|
# |100004|    Emily|1538538559000|        NextSong| free|    2|
# |100004|    Emily|1538538750000|        NextSong| free|    2|
# |100004|    Emily|1538538967000|        NextSong| free|    2|
# |100004|    Emily|1538539309000|            Home| free|    2|
# |100004|    Emily|1538751727000|        NextSong| free|    2|
# |100004|    Emily|1538751728000|       Thumbs Up| free|    2|
# |100004|    Emily|1539149098000|        NextSong| free|    2|
# |100004|    Emily|1539149382000|        NextSong| free|    2|
# |100004|    Emily|1539149592000|        NextSong| free|    2|
# |100004|    Emily|1539149787000|        NextSong| free|    2|
# |100004|    Emily|1539149788000|      Add Friend| free|    2|
# |100004|    Emily|1539149979000|        NextSong| free|    2|
# |100004|    Emily|1539150203000|        NextSong| free|    2|
# |100004|    Emily|1539150433000|        NextSong| free|    2|
# |100004|    Emily|1539387360000|        NextSong| free|    2|
# |100004|    Emily|1539387361000|       Thumbs Up| free|    2|
# |100004|    Emily|1539387605000|        NextSong| free|    2|
# |100004|    Emily|1539387898000|        NextSong| free|    2|
# |100004|    Emily|1539388117000|        NextSong| free|    2|
# |100004|    Emily|1539388118000|      Add Friend| free|    2|
# |100004|    Emily|1539388119000|      Add Friend| free|    2|
# |100004|    Emily|1539388120000|      Add Friend| free|    2|
# |100004|    Emily|1539388419000|        NextSong| free|    2|
# |100004|    Emily|1539388649000|        NextSong| free|    2|
# |100004|    Emily|1539388956000|        NextSong| free|    2|
# |100004|    Emily|1539389368000|        NextSong| free|    2|
# |100004|    Emily|1539389532000|        NextSong| free|    2|
# |100004|    Emily|1539389910000|        NextSong| free|    2|
# |100004|    Emily|1539390290000|        NextSong| free|    2|
# |100004|    Emily|1539390291000|       Thumbs Up| free|    2|
# |100004|    Emily|1539390526000|        NextSong| free|    2|
# |100004|    Emily|1539390764000|        NextSong| free|    2|
# |100004|    Emily|1539390782000|            Home| free|    2|
# |100004|    Emily|1539391000000|        NextSong| free|    2|
# |100004|    Emily|1539391069000|     Roll Advert| free|    2|
# |100004|    Emily|1539391184000|        NextSong| free|    2|
# |100004|    Emily|1539391430000|        NextSong| free|    2|
# |100004|    Emily|1539391626000|        NextSong| free|    2|
# |100004|    Emily|1539391774000|        Settings| free|    2|
# |100004|    Emily|1539391849000|        NextSong| free|    2|
# |100004|    Emily|1539392260000|        NextSong| free|    2|
# |100004|    Emily|1539392260000|     Roll Advert| free|    2|
# |100004|    Emily|1539392452000|        NextSong| free|    2|
# |100004|    Emily|1539392683000|        NextSong| free|    2|
# |100004|    Emily|1539392791000|     Roll Advert| free|    2|
# |100004|    Emily|1539392866000|        NextSong| free|    2|
# |100004|    Emily|1539393092000|     Roll Advert| free|    2|
# |100004|    Emily|1539393133000|        NextSong| free|    2|
# |100004|    Emily|1539393626000|        NextSong| free|    2|
# |100004|    Emily|1539393627000|       Thumbs Up| free|    2|
# |100004|    Emily|1539393903000|        NextSong| free|    2|
# |100004|    Emily|1539394018000|     Roll Advert| free|    2|
# |100004|    Emily|1539394113000|        NextSong| free|    2|
# |100004|    Emily|1539394375000|        NextSong| free|    2|
# |100004|    Emily|1539394400000|     Roll Advert| free|    2|
# |100004|    Emily|1539394591000|        NextSong| free|    2|
# |100004|    Emily|1539394617000|            Help| free|    2|
# |100004|    Emily|1539394809000|            Home| free|    2|
# |100004|    Emily|1539394810000|      Add Friend| free|    2|
# |100004|    Emily|1539394948000|        NextSong| free|    2|
# |100004|    Emily|1539395107000|        NextSong| free|    2|
# |100004|    Emily|1539395193000|     Roll Advert| free|    2|
# |100004|    Emily|1539395297000|        NextSong| free|    2|
# |100004|    Emily|1539395483000|        NextSong| free|    2|
# |100004|    Emily|1539395696000|        NextSong| free|    2|
# |100004|    Emily|1539395925000|        NextSong| free|    2|
# |100004|    Emily|1539396312000|        NextSong| free|    2|
# |100004|    Emily|1539396505000|        NextSong| free|    2|
# |100004|    Emily|1539396716000|        NextSong| free|    2|
# |100004|    Emily|1539396916000|        NextSong| free|    2|
# |100004|    Emily|1539396917000|       Thumbs Up| free|    2|
# |100004|    Emily|1539432317000|        NextSong| free|    2|
# |100004|    Emily|1539432539000|        NextSong| free|    2|
# |100004|    Emily|1539432787000|        NextSong| free|    2|
# |100004|    Emily|1539433009000|        NextSong| free|    2|
# |100004|    Emily|1539433201000|        NextSong| free|    2|
# |100004|    Emily|1539433385000|        NextSong| free|    2|
# |100004|    Emily|1539433579000|        NextSong| free|    2|
# |100004|    Emily|1539433801000|        NextSong| free|    2|
# |100004|    Emily|1539433878000|     Roll Advert| free|    2|
# |100004|    Emily|1539433932000|        NextSong| free|    2|
# |100004|    Emily|1539434170000|        NextSong| free|    2|
# |100004|    Emily|1539434227000|     Roll Advert| free|    2|
# |100004|    Emily|1539434312000|        NextSong| free|    2|
# |100004|    Emily|1539434581000|        NextSong| free|    2|
# |100004|    Emily|1539434893000|        NextSong| free|    2|
# |100004|    Emily|1539435079000|        NextSong| free|    2|
# |100004|    Emily|1539435274000|        NextSong| free|    2|
# |100004|    Emily|1539435367000|     Roll Advert| free|    2|
# |100004|    Emily|1539435929000|        NextSong| free|    2|
# |100004|    Emily|1539435959000|     Roll Advert| free|    2|
# |100004|    Emily|1539436275000|        NextSong| free|    2|
# |100004|    Emily|1539436498000|        NextSong| free|    2|
# |100004|    Emily|1539436724000|        NextSong| free|    2|
# |100004|    Emily|1539436942000|        NextSong| free|    2|
# |100004|    Emily|1539437372000|        NextSong| free|    2|
# |100004|    Emily|1539437616000|        NextSong| free|    2|
# |100004|    Emily|1539437869000|        NextSong| free|    2|
# |100004|    Emily|1539437870000|       Thumbs Up| free|    2|
# |100004|    Emily|1539438211000|        NextSong| free|    2|
# |100004|    Emily|1539438212000|          Logout| free|    2|
# |100004|    Emily|1539567569000|            Home| free|    2|
# |100004|    Emily|1539567605000|        NextSong| free|    2|
# |100004|    Emily|1539567909000|        NextSong| free|    2|
# |100004|    Emily|1539568268000|        NextSong| free|    2|
# |100004|    Emily|1539568551000|        NextSong| free|    2|
# |100004|    Emily|1539568855000|        NextSong| free|    2|
# |100004|    Emily|1539569109000|        NextSong| free|    2|
# |100004|    Emily|1539569306000|        NextSong| free|    2|
# |100004|    Emily|1539569338000|     Roll Advert| free|    2|
# |100004|    Emily|1539569497000|        NextSong| free|    2|
# |100004|    Emily|1539569704000|        NextSong| free|    2|
# |100004|    Emily|1539569859000|        NextSong| free|    2|
# |100004|    Emily|1539570079000|        NextSong| free|    2|
# |100004|    Emily|1539570297000|     Roll Advert| free|    2|
# |100004|    Emily|1539570515000|        NextSong| free|    2|
# |100004|    Emily|1539570772000|        NextSong| free|    2|
# |100004|    Emily|1539571167000|        NextSong| free|    2|
# |100004|    Emily|1539571178000| Add to Playlist| free|    2|
# |100004|    Emily|1539571469000|        NextSong| free|    2|
# |100004|    Emily|1539571668000|        NextSong| free|    2|
# |100004|    Emily|1539571860000|        NextSong| free|    2|
# |100004|    Emily|1539571906000|     Roll Advert| free|    2|
# |100004|    Emily|1539572075000|        NextSong| free|    2|
# |100004|    Emily|1539572307000|        NextSong| free|    2|
# |100004|    Emily|1539572618000|        NextSong| free|    2|
# |100004|    Emily|1539572722000|        NextSong| free|    2|
# |100004|    Emily|1539572954000|        NextSong| free|    2|
# |100004|    Emily|1539573160000|        NextSong| free|    2|
# |100004|    Emily|1539573449000|        NextSong| free|    2|
# |100004|    Emily|1539573450000|      Add Friend| free|    2|
# |100004|    Emily|1539573451000|      Add Friend| free|    2|
# |100004|    Emily|1539573620000|        NextSong| free|    2|
# |100004|    Emily|1539573650000|     Roll Advert| free|    2|
# |100004|    Emily|1539573918000|        NextSong| free|    2|
# |100004|    Emily|1539574092000|        NextSong| free|    2|
# |100004|    Emily|1539574318000|        NextSong| free|    2|
# |100004|    Emily|1539574357000|     Roll Advert| free|    2|
# |100004|    Emily|1539574449000|        NextSong| free|    2|
# |100004|    Emily|1539574672000|        NextSong| free|    2|
# |100004|    Emily|1539574678000|     Roll Advert| free|    2|
# |100004|    Emily|1539574773000|        NextSong| free|    2|
# |100004|    Emily|1539575028000|        NextSong| free|    2|
# |100004|    Emily|1539575277000|        NextSong| free|    2|
# |100004|    Emily|1539575498000|        NextSong| free|    2|
# |100004|    Emily|1539575704000|        NextSong| free|    2|
# |100004|    Emily|1539575998000|        NextSong| free|    2|
# |100004|    Emily|1539576041000|     Roll Advert| free|    2|
# |100004|    Emily|1539576225000|        NextSong| free|    2|
# |100004|    Emily|1539576421000|        NextSong| free|    2|
# |100004|    Emily|1539576711000|        NextSong| free|    2|
# |100004|    Emily|1539576954000|     Roll Advert| free|    2|
# |100004|    Emily|1539577002000|        NextSong| free|    2|
# |100004|    Emily|1539577106000|     Roll Advert| free|    2|
# |100004|    Emily|1539577220000|        NextSong| free|    2|
# |100004|    Emily|1539577248000|         Upgrade| free|    2|
# |100004|    Emily|1539577249000|  Submit Upgrade| free|    2|
# |100004|    Emily|1539577257000|            Home| paid|    2|
# |100004|    Emily|1539577425000|        NextSong| paid|    2|
# |100004|    Emily|1539577747000|        NextSong| paid|    2|
# |100004|    Emily|1539577748000|      Add Friend| paid|    2|
# |100004|    Emily|1539577918000|        NextSong| paid|    2|
# |100004|    Emily|1539577919000|       Thumbs Up| paid|    2|
# |100004|    Emily|1539578128000|        NextSong| paid|    2|
# |100004|    Emily|1539578350000|        NextSong| paid|    2|
# |100004|    Emily|1539578596000|        NextSong| paid|    2|
# |100004|    Emily|1539578794000|        NextSong| paid|    2|
# |100004|    Emily|1539579064000|        NextSong| paid|    2|
# |100004|    Emily|1539579305000|        NextSong| paid|    2|
# |100004|    Emily|1539579506000|            Home| paid|    2|
# |100004|    Emily|1539579665000|        NextSong| paid|    2|
# |100004|    Emily|1539579960000|        NextSong| paid|    2|
# |100004|    Emily|1539580141000|        NextSong| paid|    2|
# |100004|    Emily|1539580474000|        NextSong| paid|    2|
# |100004|    Emily|1539580687000|        NextSong| paid|    2|
# |100004|    Emily|1539580888000|        NextSong| paid|    2|
# |100004|    Emily|1539581178000|        NextSong| paid|    2|
# |100004|    Emily|1539581391000|        NextSong| paid|    2|
# |100004|    Emily|1539581445000|            Home| paid|    2|
# |100004|    Emily|1539581630000|        NextSong| paid|    2|
# |100004|    Emily|1539581845000|        NextSong| paid|    2|
# |100004|    Emily|1539582141000|        NextSong| paid|    2|
# |100004|    Emily|1539582349000|        NextSong| paid|    2|
# |100004|    Emily|1539582616000|        NextSong| paid|    2|
# |100004|    Emily|1539582747000|        NextSong| paid|    2|
# |100004|    Emily|1539583016000|        NextSong| paid|    2|
# |100004|    Emily|1539583379000|        NextSong| paid|    2|
# |100004|    Emily|1539583578000|        NextSong| paid|    2|
# |100004|    Emily|1539583579000|       Thumbs Up| paid|    2|
# |100004|    Emily|1539583591000| Add to Playlist| paid|    2|
# |100004|    Emily|1539583801000|        NextSong| paid|    2|
# |100004|    Emily|1539584108000|        NextSong| paid|    2|
# |100004|    Emily|1539584237000|        NextSong| paid|    2|
# |100004|    Emily|1539584489000|        NextSong| paid|    2|
# |100004|    Emily|1539584680000|        NextSong| paid|    2|
# |100004|    Emily|1539584846000|        NextSong| paid|    2|
# |100004|    Emily|1539584847000|       Thumbs Up| paid|    2|
# |100004|    Emily|1539601734000|        NextSong| paid|    2|
# |100004|    Emily|1539601993000|        NextSong| paid|    2|
# |100004|    Emily|1539602204000|        NextSong| paid|    2|
# |100004|    Emily|1539602315000|       Downgrade| paid|    2|
# |100004|    Emily|1539602325000|            Home| paid|    2|
# |100004|    Emily|1539602330000|        NextSong| paid|    2|
# |100004|    Emily|1539602630000|        NextSong| paid|    2|
# |100004|    Emily|1539602926000|        NextSong| paid|    2|
# |100004|    Emily|1539603233000|        NextSong| paid|    2|
# |100004|    Emily|1539603234000|          Logout| paid|    2|
# |100004|    Emily|1539864761000|            Home| paid|    2|
# |100004|    Emily|1539864762000|          Logout| paid|    2|
# |100004|    Emily|1539865500000|            Home| paid|    2|
# |100004|    Emily|1539865514000|        NextSong| paid|    2|
# |100004|    Emily|1539865734000|        NextSong| paid|    2|
# |100004|    Emily|1539865828000|        NextSong| paid|    2|
# |100004|    Emily|1539866055000|        NextSong| paid|    2|
# |100004|    Emily|1539866147000| Add to Playlist| paid|    2|
# |100004|    Emily|1539866258000|        NextSong| paid|    2|
# |100004|    Emily|1539867138000|        NextSong| paid|    2|
# |100004|    Emily|1539867357000|        NextSong| paid|    2|
# |100004|    Emily|1539867504000|     Roll Advert| paid|    2|
# |100004|    Emily|1539867579000|        NextSong| paid|    2|
# |100004|    Emily|1539867798000|        NextSong| paid|    2|
# |100004|    Emily|1539867949000| Add to Playlist| paid|    2|
# |100004|    Emily|1539868035000|        NextSong| paid|    2|
# |100004|    Emily|1539868036000|       Thumbs Up| paid|    2|
# |100004|    Emily|1539868272000|        NextSong| paid|    2|
# |100004|    Emily|1539868319000|       Downgrade| paid|    2|
# |100004|    Emily|1539868500000|        NextSong| paid|    2|
# |100004|    Emily|1539868554000|            Home| paid|    2|
# |100004|    Emily|1539868731000|       Downgrade| paid|    2|
# |100004|    Emily|1539868732000|Submit Downgrade| paid|    2|
# |100004|    Emily|1539868776000|            Home| free|    1|
# |100004|    Emily|1539868799000|        NextSong| free|    1|
# |100004|    Emily|1539868989000|        NextSong| free|    1|
# |100004|    Emily|1539869028000|     Roll Advert| free|    1|
# |100004|    Emily|1539869060000|     Roll Advert| free|    1|
# |100004|    Emily|1539869245000|        NextSong| free|    1|
# |100004|    Emily|1539869473000|     Roll Advert| free|    1|
# |100004|    Emily|1539869493000|        NextSong| free|    1|
# |100004|    Emily|1539869781000|        NextSong| free|    1|
# |100004|    Emily|1539869948000|         Upgrade| free|    1|
# |100004|    Emily|1539869991000|        NextSong| free|    1|
# |100004|    Emily|1539870206000|        NextSong| free|    1|
# |100004|    Emily|1539870609000|        NextSong| free|    1|
# |100004|    Emily|1539870610000|          Logout| free|    1|
# |100004|    Emily|1539870699000|            Home| free|    1|
# |100004|    Emily|1539870841000|        NextSong| free|    1|
# |100004|    Emily|1539870978000|     Roll Advert| free|    1|
# |100004|    Emily|1539871001000|        NextSong| free|    1|
# |100004|    Emily|1539871163000|        NextSong| free|    1|
# |100004|    Emily|1539871183000|     Roll Advert| free|    1|
# |100004|    Emily|1539871419000|        NextSong| free|    1|
# |100004|    Emily|1539871596000|     Roll Advert| free|    1|
# |100004|    Emily|1539871623000|        NextSong| free|    1|
# |100004|    Emily|1539871681000|            Home| free|    1|
# |100004|    Emily|1539872028000|        NextSong| free|    1|
# |100004|    Emily|1539872305000|        NextSong| free|    1|
# |100004|    Emily|1539872525000|        NextSong| free|    1|
# |100004|    Emily|1539872752000|        NextSong| free|    1|
# |100004|    Emily|1539872752000|     Roll Advert| free|    1|
# |100004|    Emily|1539872971000|        NextSong| free|    1|
# |100004|    Emily|1539873210000|        NextSong| free|    1|
# |100004|    Emily|1539873373000|        NextSong| free|    1|
# |100004|    Emily|1539873641000|        NextSong| free|    1|
# |100004|    Emily|1539873953000|        NextSong| free|    1|
# |100004|    Emily|1539874283000|        NextSong| free|    1|
# |100004|    Emily|1539874326000|     Roll Advert| free|    1|
# |100004|    Emily|1539874443000|        NextSong| free|    1|
# |100004|    Emily|1539874444000|      Add Friend| free|    1|
# |100004|    Emily|1539874562000|        NextSong| free|    1|
# |100004|    Emily|1539874704000|     Roll Advert| free|    1|
# |100004|    Emily|1539874852000|        NextSong| free|    1|
# |100004|    Emily|1539875184000|        NextSong| free|    1|
# |100004|    Emily|1539875415000|        NextSong| free|    1|
# |100004|    Emily|1539875547000|        NextSong| free|    1|
# |100004|    Emily|1539875775000|        NextSong| free|    1|
# |100004|    Emily|1539875854000|     Roll Advert| free|    1|
# |100004|    Emily|1539876054000|        NextSong| free|    1|
# |100004|    Emily|1539876236000|        NextSong| free|    1|
# |100004|    Emily|1539876645000|        NextSong| free|    1|
# |100004|    Emily|1539876913000|        NextSong| free|    1|
# |100004|    Emily|1539877196000|        NextSong| free|    1|
# |100004|    Emily|1539877401000|        NextSong| free|    1|
# |100004|    Emily|1539877630000|        NextSong| free|    1|
# |100004|    Emily|1539877658000|     Roll Advert| free|    1|
# |100004|    Emily|1539877812000|        NextSong| free|    1|
# |100004|    Emily|1539878007000|        NextSong| free|    1|
# |100004|    Emily|1539878256000|        NextSong| free|    1|
# |100004|    Emily|1539878493000|        NextSong| free|    1|
# |100004|    Emily|1539878603000|     Roll Advert| free|    1|
# |100004|    Emily|1539878717000|        NextSong| free|    1|
# |100004|    Emily|1539878899000|     Roll Advert| free|    1|
# |100004|    Emily|1539878915000|        NextSong| free|    1|
# |100004|    Emily|1539879126000|        NextSong| free|    1|
# |100004|    Emily|1539879403000|        NextSong| free|    1|
# |100004|    Emily|1539879690000|        NextSong| free|    1|
# |100004|    Emily|1539879852000|            Home| free|    1|
# |100004|    Emily|1539880188000|         Upgrade| free|    1|
# |100004|    Emily|1539880189000|  Submit Upgrade| free|    1|
# |100004|    Emily|1539880294000|            Home| paid|    1|
# |100004|    Emily|1539880448000|        NextSong| paid|    1|
# |100004|    Emily|1539880641000|        NextSong| paid|    1|
# |100004|    Emily|1539880821000|        NextSong| paid|    1|
# |100004|    Emily|1539881074000|        NextSong| paid|    1|
# |100004|    Emily|1539881285000|        NextSong| paid|    1|
# |100004|    Emily|1539881319000|        NextSong| paid|    1|
# |100004|    Emily|1539881499000|        NextSong| paid|    1|
# |100004|    Emily|1539881664000|        NextSong| paid|    1|
# |100004|    Emily|1539881959000|        NextSong| paid|    1|
# |100004|    Emily|1539881960000|      Add Friend| paid|    1|
# |100004|    Emily|1539882128000|        NextSong| paid|    1|
# |100004|    Emily|1539882553000|        NextSong| paid|    1|
# |100004|    Emily|1539882747000|        NextSong| paid|    1|
# |100004|    Emily|1539882977000|        NextSong| paid|    1|
# |100004|    Emily|1539883362000|        NextSong| paid|    1|
# |100004|    Emily|1539883569000|        NextSong| paid|    1|
# |100004|    Emily|1539883850000|        NextSong| paid|    1|
# |100004|    Emily|1539884080000|        NextSong| paid|    1|
# |100004|    Emily|1539884218000|        NextSong| paid|    1|
# |100004|    Emily|1539884386000| Add to Playlist| paid|    1|
# |100004|    Emily|1539884456000|        NextSong| paid|    1|
# |100004|    Emily|1539884848000|        NextSong| paid|    1|
# |100004|    Emily|1539885025000|        NextSong| paid|    1|
# |100004|    Emily|1539885270000|        NextSong| paid|    1|
# |100004|    Emily|1539885432000|        NextSong| paid|    1|
# |100004|    Emily|1539885660000|        NextSong| paid|    1|
# |100004|    Emily|1539885856000|        NextSong| paid|    1|
# |100004|    Emily|1539886077000|        NextSong| paid|    1|
# |100004|    Emily|1539886278000|        NextSong| paid|    1|
# |100004|    Emily|1539886402000|        NextSong| paid|    1|
# |100004|    Emily|1539886680000|        NextSong| paid|    1|
# |100004|    Emily|1539887013000|        NextSong| paid|    1|
# |100004|    Emily|1539887232000|        NextSong| paid|    1|
# |100004|    Emily|1539887480000|        NextSong| paid|    1|
# |100004|    Emily|1539887679000|        NextSong| paid|    1|
# |100004|    Emily|1539887982000|        NextSong| paid|    1|
# |100004|    Emily|1539888035000|       Downgrade| paid|    1|
# |100004|    Emily|1539888035000|            Help| paid|    1|
# |100004|    Emily|1539888081000|            Home| paid|    1|
# |100004|    Emily|1539888297000|        NextSong| paid|    1|
# |100004|    Emily|1539888495000|        NextSong| paid|    1|
# |100004|    Emily|1539888706000|        NextSong| paid|    1|
# |100004|    Emily|1539888899000|        NextSong| paid|    1|
# |100004|    Emily|1539889065000|        NextSong| paid|    1|
# |100004|    Emily|1539889369000|        NextSong| paid|    1|
# |100004|    Emily|1539889517000|        NextSong| paid|    1|
# |100004|    Emily|1539889754000|        NextSong| paid|    1|
# |100004|    Emily|1539889959000|        NextSong| paid|    1|
# |100004|    Emily|1539889960000|       Thumbs Up| paid|    1|
# |100004|    Emily|1539890188000|        NextSong| paid|    1|
# |100004|    Emily|1539890189000|       Thumbs Up| paid|    1|
# |100004|    Emily|1539890369000|        NextSong| paid|    1|
# |100004|    Emily|1539890552000|        NextSong| paid|    1|
# |100004|    Emily|1539890840000|        NextSong| paid|    1|
# |100004|    Emily|1539891055000|        NextSong| paid|    1|
# |100004|    Emily|1539891255000|        NextSong| paid|    1|
# |100004|    Emily|1539891445000|        NextSong| paid|    1|
# |100004|    Emily|1539891716000|        NextSong| paid|    1|
# |100004|    Emily|1539891886000| Add to Playlist| paid|    1|
# |100004|    Emily|1539892152000|        NextSong| paid|    1|
# |100004|    Emily|1539892367000|        NextSong| paid|    1|
# |100004|    Emily|1539892673000|        NextSong| paid|    1|
# |100004|    Emily|1539892893000|        NextSong| paid|    1|
# |100004|    Emily|1539893177000|        NextSong| paid|    1|
# |100004|    Emily|1539893178000|          Logout| paid|    1|
# |100004|    Emily|1539893334000|            Home| paid|    1|
# |100004|    Emily|1539893385000|        NextSong| paid|    1|
# |100004|    Emily|1539893594000|        NextSong| paid|    1|
# |100004|    Emily|1539893757000|        NextSong| paid|    1|
# |100004|    Emily|1539893943000|        NextSong| paid|    1|
# |100004|    Emily|1539894283000|        NextSong| paid|    1|
# |100004|    Emily|1539894539000|        NextSong| paid|    1|
# |100004|    Emily|1539894719000|     Roll Advert| paid|    1|
# |100004|    Emily|1539894816000|        NextSong| paid|    1|
# |100004|    Emily|1539895078000|        NextSong| paid|    1|
# |100004|    Emily|1539895291000|        NextSong| paid|    1|
# |100004|    Emily|1539895550000|        NextSong| paid|    1|
# |100004|    Emily|1539895788000|        NextSong| paid|    1|
# |100004|    Emily|1539896030000|        NextSong| paid|    1|
# |100004|    Emily|1539896398000|        NextSong| paid|    1|
# |100004|    Emily|1539896399000|          Logout| paid|    1|
# |100004|    Emily|1540315019000|            Home| paid|    1|
# |100004|    Emily|1540315160000|        NextSong| paid|    1|
# |100004|    Emily|1540315388000|        NextSong| paid|    1|
# |100004|    Emily|1540315717000|        NextSong| paid|    1|
# |100004|    Emily|1540315995000|        NextSong| paid|    1|
# |100004|    Emily|1540315996000|     Thumbs Down| paid|    1|
# |100004|    Emily|1540316223000|        NextSong| paid|    1|
# |100004|    Emily|1540316511000|        NextSong| paid|    1|
# |100004|    Emily|1540316747000|        NextSong| paid|    1|
# |100004|    Emily|1540463992000|            Home| paid|    1|
# |100004|    Emily|1540463998000|        NextSong| paid|    1|
# |100004|    Emily|1540464318000|        NextSong| paid|    1|
# |100004|    Emily|1540464482000|        NextSong| paid|    1|
# |100004|    Emily|1540464562000|     Roll Advert| paid|    1|
# |100004|    Emily|1540464673000|        NextSong| paid|    1|
# |100004|    Emily|1540464880000|        NextSong| paid|    1|
# |100004|    Emily|1540465107000|        NextSong| paid|    1|
# |100004|    Emily|1540465253000| Add to Playlist| paid|    1|
# |100004|    Emily|1540465312000|        NextSong| paid|    1|
# |100004|    Emily|1540465617000|        NextSong| paid|    1|
# |100004|    Emily|1540466012000|        NextSong| paid|    1|
# |100004|    Emily|1540466186000|        NextSong| paid|    1|
# |100004|    Emily|1540466415000|        NextSong| paid|    1|
# |100004|    Emily|1540466560000|        NextSong| paid|    1|
# |100004|    Emily|1540466726000|        NextSong| paid|    1|
# |100004|    Emily|1540466980000|        NextSong| paid|    1|
# |100004|    Emily|1540467227000| Add to Playlist| paid|    1|
# |100004|    Emily|1540467348000|        NextSong| paid|    1|
# |100004|    Emily|1540467349000|          Logout| paid|    1|
# |100004|    Emily|1540467677000|            Home| paid|    1|
# |100004|    Emily|1540513436000|        NextSong| paid|    1|
# |100004|    Emily|1540513708000|        NextSong| paid|    1|
# |100004|    Emily|1540514019000|        NextSong| paid|    1|
# |100004|    Emily|1540514082000|        Settings| paid|    1|
# |100004|    Emily|1540514238000|            Home| paid|    1|
# |100004|    Emily|1540961646000|        NextSong| paid|    1|
# |100004|    Emily|1540961856000|        NextSong| paid|    1|
# |100004|    Emily|1540962095000|        NextSong| paid|    1|
# |100004|    Emily|1540962443000|        NextSong| paid|    1|
# |100004|    Emily|1540962864000|        NextSong| paid|    1|
# |100004|    Emily|1540962906000|        NextSong| paid|    1|
# |100004|    Emily|1540963245000|        NextSong| paid|    1|
# |100004|    Emily|1540963325000|       Downgrade| paid|    1|
# |100004|    Emily|1540963486000|        NextSong| paid|    1|
# |100004|    Emily|1540963671000|        NextSong| paid|    1|
# |100004|    Emily|1540963866000|        NextSong| paid|    1|
# |100004|    Emily|1540964180000|        NextSong| paid|    1|
# |100004|    Emily|1540964463000|        NextSong| paid|    1|
# |100004|    Emily|1540964712000|        NextSong| paid|    1|
# |100004|    Emily|1540964918000|        NextSong| paid|    1|
# |100004|    Emily|1540965573000|        NextSong| paid|    1|
# |100004|    Emily|1540965826000|        NextSong| paid|    1|
# |100004|    Emily|1540966228000|        NextSong| paid|    1|
# |100004|    Emily|1540966685000|        NextSong| paid|    1|
# |100004|    Emily|1540966725000|       Downgrade| paid|    1|
# |100004|    Emily|1540966823000|        NextSong| paid|    1|
# |100004|    Emily|1540966874000|       Downgrade| paid|    1|
# |100004|    Emily|1540967068000|        NextSong| paid|    1|
# |100004|    Emily|1540967267000| Add to Playlist| paid|    1|
# |100004|    Emily|1540967347000|        NextSong| paid|    1|
# |100004|    Emily|1540967509000|        NextSong| paid|    1|
# |100004|    Emily|1540967603000| Add to Playlist| paid|    1|
# |100004|    Emily|1540967743000|        NextSong| paid|    1|
# |100004|    Emily|1540968021000|        NextSong| paid|    1|
# |100004|    Emily|1540968230000|        NextSong| paid|    1|
# |100004|    Emily|1540968448000|        NextSong| paid|    1|
# |100004|    Emily|1540968708000|        NextSong| paid|    1|
# |100004|    Emily|1540968951000|        NextSong| paid|    1|
# |100004|    Emily|1540969211000|        NextSong| paid|    1|
# |100004|    Emily|1540969568000|        NextSong| paid|    1|
# |100004|    Emily|1540969854000|        NextSong| paid|    1|
# |100004|    Emily|1540970100000|        NextSong| paid|    1|
# |100004|    Emily|1540970258000|        NextSong| paid|    1|
# |100004|    Emily|1540970644000|        NextSong| paid|    1|
# |100004|    Emily|1540970874000|        NextSong| paid|    1|
# |100004|    Emily|1540971072000|        NextSong| paid|    1|
# |100004|    Emily|1540971331000|        NextSong| paid|    1|
# |100004|    Emily|1540971332000|       Thumbs Up| paid|    1|
# |100004|    Emily|1540971601000|        NextSong| paid|    1|
# |100004|    Emily|1540971768000|        NextSong| paid|    1|
# |100004|    Emily|1540971912000|        NextSong| paid|    1|
# |100004|    Emily|1540972123000|        NextSong| paid|    1|
# |100004|    Emily|1540972328000|        NextSong| paid|    1|
# |100004|    Emily|1540972601000|        NextSong| paid|    1|
# |100004|    Emily|1540972824000|        NextSong| paid|    1|
# |100004|    Emily|1540972974000|        NextSong| paid|    1|
# |100004|    Emily|1540973279000|        NextSong| paid|    1|
# |100004|    Emily|1540973531000|        NextSong| paid|    1|
# |100004|    Emily|1540973841000|        NextSong| paid|    1|
# |100004|    Emily|1540974067000|        NextSong| paid|    1|
# |100004|    Emily|1540974115000|            Help| paid|    1|
# |100004|    Emily|1540974431000|        NextSong| paid|    1|
# |100004|    Emily|1540974651000|        NextSong| paid|    1|
# |100004|    Emily|1540974677000|     Roll Advert| paid|    1|
# |100004|    Emily|1540974842000|        NextSong| paid|    1|
# |100004|    Emily|1540974843000|          Logout| paid|    1|
# |100004|    Emily|1540974990000|            Home| paid|    1|
# |100004|    Emily|1540975129000|        Settings| paid|    1|
# |100004|    Emily|1540975221000|       Downgrade| paid|    1|
# |100004|    Emily|1540975222000|Submit Downgrade| paid|    1|
# |100004|    Emily|1540975345000|            Home| free|    0|
# |100004|    Emily|1540975381000|        NextSong| free|    0|
# |100004|    Emily|1540975763000|     Roll Advert| free|    0|
# |100004|    Emily|1540975766000|        NextSong| free|    0|
# |100004|    Emily|1540975855000|            Help| free|    0|
# |100004|    Emily|1540975864000|            Home| free|    0|
# |100004|    Emily|1540976019000|        NextSong| free|    0|
# |100004|    Emily|1540976339000|        NextSong| free|    0|
# |100004|    Emily|1540976664000|        NextSong| free|    0|
# |100004|    Emily|1540976665000|     Thumbs Down| free|    0|
# |100004|    Emily|1540977014000|        NextSong| free|    0|
# |100004|    Emily|1540977062000|           Error| free|    0|
# |100004|    Emily|1540977356000|        NextSong| free|    0|
# |100004|    Emily|1540977622000|        NextSong| free|    0|
# |100004|    Emily|1540978044000| Add to Playlist| free|    0|
# |100004|    Emily|1540978055000|        NextSong| free|    0|
# |100004|    Emily|1540978291000|        NextSong| free|    0|
# |100004|    Emily|1540978639000|        NextSong| free|    0|
# |100004|    Emily|1540978837000|        NextSong| free|    0|
# |100004|    Emily|1540979147000|        NextSong| free|    0|
# |100004|    Emily|1540979367000|        NextSong| free|    0|
# |100004|    Emily|1540979509000|        NextSong| free|    0|
# |100004|    Emily|1540979778000|        NextSong| free|    0|
# |100004|    Emily|1540979877000|        NextSong| free|    0|
# |100004|    Emily|1540980141000|        NextSong| free|    0|
# |100004|    Emily|1540980251000|        Settings| free|    0|
# |100004|    Emily|1540980290000|        NextSong| free|    0|
# |100004|    Emily|1540980564000|        NextSong| free|    0|
# |100004|    Emily|1540980569000|     Roll Advert| free|    0|
# |100004|    Emily|1540980759000|        NextSong| free|    0|
# |100004|    Emily|1540981024000|        NextSong| free|    0|
# |100004|    Emily|1540981457000|        NextSong| free|    0|
# |100004|    Emily|1540981703000|        NextSong| free|    0|
# |100004|    Emily|1540981704000|     Thumbs Down| free|    0|
# |100004|    Emily|1540981963000|        NextSong| free|    0|
# |100004|    Emily|1540982105000|     Roll Advert| free|    0|
# |100004|    Emily|1540982159000|        NextSong| free|    0|
# |100004|    Emily|1540982365000|        NextSong| free|    0|
# |100004|    Emily|1540982602000|        NextSong| free|    0|
# |100004|    Emily|1540982669000|     Roll Advert| free|    0|
# |100004|    Emily|1540982822000|        NextSong| free|    0|
# |100004|    Emily|1540983007000|        NextSong| free|    0|
# |100004|    Emily|1540983190000|        NextSong| free|    0|
# |100004|    Emily|1540983464000|        NextSong| free|    0|
# |100004|    Emily|1540983736000|        NextSong| free|    0|
# |100004|    Emily|1540984089000|        NextSong| free|    0|
# |100004|    Emily|1540984126000|            Home| free|    0|
# |100004|    Emily|1540984350000|        NextSong| free|    0|
# |100004|    Emily|1540984583000|        NextSong| free|    0|
# |100004|    Emily|1540984797000|        NextSong| free|    0|
# |100004|    Emily|1540984798000|       Thumbs Up| free|    0|
# |100004|    Emily|1540985096000|        NextSong| free|    0|
# |100004|    Emily|1540985253000|        NextSong| free|    0|
# |100004|    Emily|1540985335000|            Home| free|    0|
# |100004|    Emily|1540985470000|        NextSong| free|    0|
# |100004|    Emily|1540985568000|        NextSong| free|    0|
# |100004|    Emily|1540985569000|          Logout| free|    0|
# |100004|    Emily|1541411402000|            Home| free|    0|
# |100004|    Emily|1541411625000|        NextSong| free|    0|
# |100004|    Emily|1541411775000|        NextSong| free|    0|
# |100004|    Emily|1541412290000|        NextSong| free|    0|
# |100004|    Emily|1541412291000|       Thumbs Up| free|    0|
# |100004|    Emily|1541412585000|        NextSong| free|    0|
# |100004|    Emily|1541412638000|        NextSong| free|    0|
# |100004|    Emily|1541412902000|        NextSong| free|    0|
# |100004|    Emily|1541413096000|        NextSong| free|    0|
# |100004|    Emily|1541413563000|        NextSong| free|    0|
# |100004|    Emily|1541413862000|        NextSong| free|    0|
# |100004|    Emily|1541414105000|        NextSong| free|    0|
# |100004|    Emily|1541414384000|        NextSong| free|    0|
# |100004|    Emily|1541414593000|        NextSong| free|    0|
# |100004|    Emily|1541414608000|            Home| free|    0|
# |100004|    Emily|1541414609000|          Logout| free|    0|
# |100004|    Emily|1541414922000|            Home| free|    0|
# |100004|    Emily|1541414927000|        NextSong| free|    0|
# |100004|    Emily|1541415266000|        NextSong| free|    0|
# |100004|    Emily|1541416751000|        NextSong| free|    0|
# |100004|    Emily|1541417100000|        NextSong| free|    0|
# |100004|    Emily|1541417305000|        NextSong| free|    0|
# |100004|    Emily|1541417319000|     Roll Advert| free|    0|
# |100004|    Emily|1541417585000|        NextSong| free|    0|
# |100004|    Emily|1541417980000|        NextSong| free|    0|
# |100004|    Emily|1541417981000|          Logout| free|    0|
# |100004|    Emily|1542069587000|            Home| free|    0|
# |100004|    Emily|1542069615000|        NextSong| free|    0|
# |100004|    Emily|1542069737000|     Roll Advert| free|    0|
# |100004|    Emily|1542069842000|        NextSong| free|    0|
# |100004|    Emily|1542070025000|        NextSong| free|    0|
# |100004|    Emily|1542070185000|     Roll Advert| free|    0|
# |100004|    Emily|1542070269000|        NextSong| free|    0|
# |100004|    Emily|1542070467000|        NextSong| free|    0|
# |100004|    Emily|1542070674000|        NextSong| free|    0|
# |100004|    Emily|1542071388000|        NextSong| free|    0|
# |100004|    Emily|1542071833000|        NextSong| free|    0|
# |100004|    Emily|1542072013000|        NextSong| free|    0|
# |100004|    Emily|1542072275000|        NextSong| free|    0|
# |100004|    Emily|1542072341000|        Settings| free|    0|
# |100004|    Emily|1542072509000|        NextSong| free|    0|
# |100004|    Emily|1542072788000|        NextSong| free|    0|
# |100004|    Emily|1542073024000|        NextSong| free|    0|
# |100004|    Emily|1542073278000|        NextSong| free|    0|
# |100004|    Emily|1542073454000|        NextSong| free|    0|
# |100004|    Emily|1542073655000|        NextSong| free|    0|
# |100004|    Emily|1542073790000| Add to Playlist| free|    0|
# |100004|    Emily|1542073896000|        NextSong| free|    0|
# |100004|    Emily|1542074194000|        NextSong| free|    0|
# |100004|    Emily|1542074398000|        NextSong| free|    0|
# |100004|    Emily|1542074700000|        NextSong| free|    0|
# |100004|    Emily|1542074707000| Add to Playlist| free|    0|
# |100004|    Emily|1542074890000|        NextSong| free|    0|
# |100004|    Emily|1542075179000|        NextSong| free|    0|
# |100004|    Emily|1542075466000|        NextSong| free|    0|
# |100004|    Emily|1542075703000|        NextSong| free|    0|
# |100004|    Emily|1542075959000|        NextSong| free|    0|
# |100004|    Emily|1542075960000|          Logout| free|    0|
# |100004|    Emily|1542076210000|            Home| free|    0|
# |100004|    Emily|1542076229000|        NextSong| free|    0|
# |100004|    Emily|1542076478000|        NextSong| free|    0|
# |100004|    Emily|1542076479000|       Thumbs Up| free|    0|
# |100004|    Emily|1542076713000|        NextSong| free|    0|
# |100004|    Emily|1542076926000|        NextSong| free|    0|
# |100004|    Emily|1542077132000|        NextSong| free|    0|
# |100004|    Emily|1542077357000|        NextSong| free|    0|
# |100004|    Emily|1542077609000|        NextSong| free|    0|
# |100004|    Emily|1542077651000|     Roll Advert| free|    0|
# |100004|    Emily|1542077850000|        NextSong| free|    0|
# |100004|    Emily|1542078012000|     Roll Advert| free|    0|
# |100004|    Emily|1542078121000|        NextSong| free|    0|
# |100004|    Emily|1542078393000|        NextSong| free|    0|
# |100004|    Emily|1542078537000|        NextSong| free|    0|
# |100004|    Emily|1542078775000|        NextSong| free|    0|
# |100004|    Emily|1542079043000|        NextSong| free|    0|
# |100004|    Emily|1542079044000|      Add Friend| free|    0|
# |100004|    Emily|1542079391000|        NextSong| free|    0|
# |100004|    Emily|1542079442000|     Roll Advert| free|    0|
# |100004|    Emily|1542079619000|        NextSong| free|    0|
# |100004|    Emily|1542079870000|     Roll Advert| free|    0|
# |100004|    Emily|1542080074000|     Roll Advert| free|    0|
# |100004|    Emily|1542080113000|        NextSong| free|    0|
# |100004|    Emily|1542080154000|     Roll Advert| free|    0|
# |100004|    Emily|1542080200000|        NextSong| free|    0|
# |100004|    Emily|1542080344000|        NextSong| free|    0|
# |100004|    Emily|1542080582000|        NextSong| free|    0|
# |100004|    Emily|1542080749000|        NextSong| free|    0|
# |100004|    Emily|1542080750000|       Thumbs Up| free|    0|
# |100004|    Emily|1542080916000|        NextSong| free|    0|
# |100004|    Emily|1542081144000|        NextSong| free|    0|
# |100004|    Emily|1542081492000|        NextSong| free|    0|
# |100004|    Emily|1542081815000|        NextSong| free|    0|
# |100004|    Emily|1542082031000|        NextSong| free|    0|
# |100004|    Emily|1542082211000|        NextSong| free|    0|
# |100004|    Emily|1542082446000|     Roll Advert| free|    0|
# |100004|    Emily|1542082463000|        NextSong| free|    0|
# |100004|    Emily|1542082749000|        NextSong| free|    0|
# |100004|    Emily|1542082826000|     Roll Advert| free|    0|
# |100004|    Emily|1542082876000|     Roll Advert| free|    0|
# |100004|    Emily|1542082971000|        NextSong| free|    0|
# |100004|    Emily|1542083188000|        NextSong| free|    0|
# |100004|    Emily|1542083455000|        NextSong| free|    0|
# |100004|    Emily|1542083460000|     Roll Advert| free|    0|
# |100004|    Emily|1542083646000|        NextSong| free|    0|
# |100004|    Emily|1542083872000|        NextSong| free|    0|
# |100004|    Emily|1542083873000| Add to Playlist| free|    0|
# |100004|    Emily|1542083874000|       Thumbs Up| free|    0|
# |100004|    Emily|1542084089000|        NextSong| free|    0|
# |100004|    Emily|1542084256000|        NextSong| free|    0|
# |100004|    Emily|1542084416000|        NextSong| free|    0|
# |100004|    Emily|1542084653000|        NextSong| free|    0|
# |100004|    Emily|1542084754000|     Roll Advert| free|    0|
# |100004|    Emily|1542084840000|         Upgrade| free|    0|
# |100004|    Emily|1542084841000|        NextSong| free|    0|
# |100004|    Emily|1542085042000|        NextSong| free|    0|
# |100004|    Emily|1542085278000|        NextSong| free|    0|
# |100004|    Emily|1542085317000|            Home| free|    0|
# |100004|    Emily|1542085510000|        NextSong| free|    0|
# |100004|    Emily|1542085720000|        NextSong| free|    0|
# |100004|    Emily|1542085899000|        NextSong| free|    0|
# |100004|    Emily|1542086084000|        NextSong| free|    0|
# |100004|    Emily|1542086280000|        NextSong| free|    0|
# |100004|    Emily|1542086519000|        NextSong| free|    0|
# |100004|    Emily|1542086520000|     Thumbs Down| free|    0|
# |100004|    Emily|1542086786000|        NextSong| free|    0|
# |100004|    Emily|1542086787000|       Thumbs Up| free|    0|
# |100004|    Emily|1542087408000|        NextSong| free|    0|
# |100004|    Emily|1542087804000|     Roll Advert| free|    0|
# |100004|    Emily|1542087988000|        NextSong| free|    0|
# |100004|    Emily|1542088157000|     Roll Advert| free|    0|
# |100004|    Emily|1542088239000|        NextSong| free|    0|
# |100004|    Emily|1542088414000|        NextSong| free|    0|
# |100004|    Emily|1542088415000|       Thumbs Up| free|    0|
# |100004|    Emily|1542088668000|        NextSong| free|    0|
# |100004|    Emily|1542088994000|        NextSong| free|    0|
# |100004|    Emily|1542089317000|     Roll Advert| free|    0|
# |100004|    Emily|1542089337000|        NextSong| free|    0|
# |100004|    Emily|1542089480000|        NextSong| free|    0|
# |100004|    Emily|1542089697000|        NextSong| free|    0|
# |100004|    Emily|1542089698000|          Logout| free|    0|
# |100004|    Emily|1542103786000|            Home| free|    0|
# |100004|    Emily|1542104029000|        NextSong| free|    0|
# |100004|    Emily|1542104180000|        NextSong| free|    0|
# |100004|    Emily|1542104380000|        NextSong| free|    0|
# |100004|    Emily|1542104643000|        NextSong| free|    0|
# |100004|    Emily|1542104827000|        NextSong| free|    0|
# |100004|    Emily|1542105030000|        NextSong| free|    0|
# |100004|    Emily|1542105031000|       Thumbs Up| free|    0|
# |100004|    Emily|1542105221000|        NextSong| free|    0|
# |100004|    Emily|1542105222000|       Thumbs Up| free|    0|
# |100004|    Emily|1542105499000|        NextSong| free|    0|
# |100004|    Emily|1542105743000|        NextSong| free|    0|
# |100004|    Emily|1542106003000|        NextSong| free|    0|
# |100004|    Emily|1542106242000|        NextSong| free|    0|
# |100004|    Emily|1542106458000|        NextSong| free|    0|
# |100004|    Emily|1542106459000|       Thumbs Up| free|    0|
# |100004|    Emily|1542106742000|        NextSong| free|    0|
# |100004|    Emily|1542106743000|      Add Friend| free|    0|
# |100004|    Emily|1542106913000|        NextSong| free|    0|
# |100004|    Emily|1542107140000|        NextSong| free|    0|
# |100004|    Emily|1542107162000|         Upgrade| free|    0|
# |100004|    Emily|1542107395000|        NextSong| free|    0|
# |100004|    Emily|1542107647000|        NextSong| free|    0|
# |100004|    Emily|1542107915000|        NextSong| free|    0|
# |100004|    Emily|1542108140000|        NextSong| free|    0|
# |100004|    Emily|1542108261000|        NextSong| free|    0|
# |100004|    Emily|1542108673000|        NextSong| free|    0|
# |100004|    Emily|1542108872000|        NextSong| free|    0|
# |100004|    Emily|1542109111000|        NextSong| free|    0|
# |100004|    Emily|1542109288000|        NextSong| free|    0|
# |100004|    Emily|1542109502000|        NextSong| free|    0|
# |100004|    Emily|1542109746000|        NextSong| free|    0|
# |100004|    Emily|1542109846000| Add to Playlist| free|    0|
# |100004|    Emily|1542110050000|        NextSong| free|    0|
# |100004|    Emily|1542110051000|     Thumbs Down| free|    0|
# |100004|    Emily|1542110311000|        NextSong| free|    0|
# |100004|    Emily|1542110458000|        NextSong| free|    0|
# |100004|    Emily|1542110459000|      Add Friend| free|    0|
# |100004|    Emily|1542110460000|      Add Friend| free|    0|
# |100004|    Emily|1542110479000|            Home| free|    0|
# |100004|    Emily|1542110524000|        NextSong| free|    0|
# |100004|    Emily|1542110734000|        NextSong| free|    0|
# |100004|    Emily|1542110735000|     Thumbs Down| free|    0|
# |100004|    Emily|1542111030000|        NextSong| free|    0|
# |100004|    Emily|1542111150000|        NextSong| free|    0|
# |100004|    Emily|1542111389000|        NextSong| free|    0|
# |100004|    Emily|1542111685000|        NextSong| free|    0|
# |100004|    Emily|1542111686000|          Logout| free|    0|
# |100004|    Emily|1542111717000|            Home| free|    0|
# |100004|    Emily|1542111950000|        NextSong| free|    0|
# |100004|    Emily|1542112099000|        NextSong| free|    0|
# |100004|    Emily|1542112303000|        NextSong| free|    0|
# |100004|    Emily|1542112304000|          Logout| free|    0|
# |100004|    Emily|1542143145000|            Home| free|    0|
# |100004|    Emily|1542299194000|            Home| free|    0|
# |100004|    Emily|1542299221000|        NextSong| free|    0|
# |100004|    Emily|1542299412000|        NextSong| free|    0|
# |100004|    Emily|1542299688000|        NextSong| free|    0|
# |100004|    Emily|1542299976000|        NextSong| free|    0|
# |100004|    Emily|1542299986000|     Roll Advert| free|    0|
# |100004|    Emily|1542300397000|        NextSong| free|    0|
# |100004|    Emily|1542300507000|     Roll Advert| free|    0|
# |100004|    Emily|1542300533000|        NextSong| free|    0|
# |100004|    Emily|1542300882000|        NextSong| free|    0|
# |100004|    Emily|1542301112000|        NextSong| free|    0|
# |100004|    Emily|1542301356000|        NextSong| free|    0|
# |100004|    Emily|1542301639000|        NextSong| free|    0|
# |100004|    Emily|1542301862000|        NextSong| free|    0|
# |100004|    Emily|1542302176000|        NextSong| free|    0|
# |100004|    Emily|1542302474000|        NextSong| free|    0|
# |100004|    Emily|1542302732000|        NextSong| free|    0|
# |100004|    Emily|1542302944000|        NextSong| free|    0|
# |100004|    Emily|1542303149000|        NextSong| free|    0|
# |100004|    Emily|1542303335000|        NextSong| free|    0|
# |100004|    Emily|1542303548000|     Roll Advert| free|    0|
# |100004|    Emily|1542303607000|        NextSong| free|    0|
# |100004|    Emily|1542303706000|         Upgrade| free|    0|
# |100004|    Emily|1542303772000|        NextSong| free|    0|
# |100004|    Emily|1542303819000|     Roll Advert| free|    0|
# |100004|    Emily|1542303932000|        NextSong| free|    0|
# |100004|    Emily|1542303981000|     Roll Advert| free|    0|
# |100004|    Emily|1542304135000|        NextSong| free|    0|
# |100004|    Emily|1542304448000|        NextSong| free|    0|
# |100004|    Emily|1542304583000|            Home| free|    0|
# |100004|    Emily|1542304706000|            Help| free|    0|
# |100004|    Emily|1542304786000|        NextSong| free|    0|
# |100004|    Emily|1542305161000|        Settings| free|    0|
# |100004|    Emily|1542305292000|        NextSong| free|    0|
# |100004|    Emily|1542305548000|        NextSong| free|    0|
# |100004|    Emily|1542305727000|        NextSong| free|    0|
# |100004|    Emily|1542305728000|     Thumbs Down| free|    0|
# |100004|    Emily|1542305968000|        NextSong| free|    0|
# |100004|    Emily|1542305969000|       Thumbs Up| free|    0|
# |100004|    Emily|1542306181000|        NextSong| free|    0|
# |100004|    Emily|1542306188000|     Roll Advert| free|    0|
# |100004|    Emily|1542306463000|        NextSong| free|    0|
# |100004|    Emily|1542306730000|        NextSong| free|    0|
# |100004|    Emily|1542306756000|     Roll Advert| free|    0|
# |100004|    Emily|1542306851000|        NextSong| free|    0|
# |100004|    Emily|1542306853000| Add to Playlist| free|    0|
# |100004|    Emily|1542307068000|        NextSong| free|    0|
# |100004|    Emily|1542307311000|        NextSong| free|    0|
# |100004|    Emily|1542307543000|        NextSong| free|    0|
# +------+---------+-------------+----------------+-----+-----+
# only showing top 800 rows
